# %% [markdown]
# # Prepare dataset filtering

# %%
import os
import shutil
import pandas as pd
from collections import defaultdict
import random

# %%
base_dataset_path = 'dataset' # Asume que tu notebook está al mismo nivel que la carpeta 'dataset'

train_path_original = os.path.join(base_dataset_path, 'train')
test_path_original = os.path.join(base_dataset_path, 'test')
valid_path_original = os.path.join(base_dataset_path, 'valid')

print(f"Ruta de entrenamiento original: {train_path_original}")
print(f"Ruta de prueba original: {test_path_original}")
print(f"Ruta de validación original: {valid_path_original}")
# Out:
# Ruta de entrenamiento original: dataset/train
# Ruta de prueba original: dataset/test
# Ruta de validación original: dataset/valid

# %%
species_counts = defaultdict(int)

# Recorrer cada carpeta de especie dentro de 'train'
for species_folder in os.listdir(train_path_original):
    species_folder_path = os.path.join(train_path_original, species_folder)
    if os.path.isdir(species_folder_path): # Asegurarse de que sea una carpeta
        # Contar el número de archivos (imágenes) en la carpeta de la especie
        num_images = len([name for name in os.listdir(species_folder_path) if os.path.isfile(os.path.join(species_folder_path, name))])
        species_counts[species_folder] = num_images

# Convertir a un DataFrame para fácil visualización y ordenamiento
df_species_counts = pd.DataFrame(species_counts.items(), columns=['Species', 'Count'])
df_species_counts = df_species_counts.sort_values(by='Count', ascending=False).reset_index(drop=True)

print("Cantidad de muestras por especie en el conjunto de entrenamiento (ordenado de mayor a menor):")
print(df_species_counts.head()) # Mostrar las primeras para verificar
print(f"\nTotal de especies encontradas: {len(df_species_counts)}")
# Out:
# Cantidad de muestras por especie en el conjunto de entrenamiento (ordenado de mayor a menor):
#             Species  Count
# 0    MOURNING CLOAK    187
# 1  GREEN HAIRSTREAK    176
# 2       BROWN ARGUS    169
# 3  BROOKES BIRDWING    165
# 4     SLEEPY ORANGE    153
#
# Total de especies encontradas: 100

# %%
top_30_species = df_species_counts.head(30)['Species'].tolist()

print("\nLas 30 especies con la mayor cantidad de muestras son:")
for i, species in enumerate(top_30_species):
    print(f"{i+1}. {species}")

print(f"\nTotal de especies seleccionadas: {len(top_30_species)}")
# Out:
# Las 30 especies con la mayor cantidad de muestras son:
# 1. MOURNING CLOAK
# 2. GREEN HAIRSTREAK
# 3. BROWN ARGUS
# 4. BROOKES BIRDWING
# 5. SLEEPY ORANGE
# 6. CHALK HILL BLUE
# 7. WHITE LINED SPHINX MOTH
# 8. HUMMING BIRD HAWK MOTH
# 9. ATALA
# 10. BROWN SIPROETA
# 11. ARCIGERA FLOWER MOTH
# 12. SCARCE SWALLOW
# 13. BANDED ORANGE HELICONIAN
# 14. CRECENT
# 15. MILBERTS TORTOISESHELL
# 16. RED CRACKER
# 17. ROSY MAPLE MOTH
# 18. ORANGE TIP
# 19. HERCULES MOTH
# 20. BANDED TIGER MOTH
# 21. Iphiclus sister
# 22. EASTERN PINE ELFIN
# 23. EMPEROR GUM MOTH
# 24. CHECQUERED SKIPPER
# 25. GREAT JAY
# 26. DANAID EGGFLY
# 27. COPPER TAIL
# 28. EASTERN COMA
# 29. BIRD CHERRY ERMINE MOTH
# 30. CLEOPATRA
#
# Total de especies seleccionadas: 30

# %% [markdown]
# # Create filtered dataset

# %%
filtered_dataset_path = 'filtered_dataset'
filtered_train_path = os.path.join(filtered_dataset_path, 'train')
filtered_test_path = os.path.join(filtered_dataset_path, 'test')
filtered_valid_path = os.path.join(filtered_dataset_path, 'valid')

# Crear las carpetas base del dataset filtrado si no existen
os.makedirs(filtered_train_path, exist_ok=True)
os.makedirs(filtered_test_path, exist_ok=True)
os.makedirs(filtered_valid_path, exist_ok=True)

print(f"\nCreando la estructura de carpetas en: {filtered_dataset_path}")

# Función para copiar carpetas de especies
def copy_species_folders(source_base, destination_base, species_list):
    for species in species_list:
        source_species_path = os.path.join(source_base, species)
        destination_species_path = os.path.join(destination_base, species)

        if os.path.exists(source_species_path):
            shutil.copytree(source_species_path, destination_species_path, dirs_exist_ok=True)
            print(f"Copiado: {source_species_path} a {destination_species_path}")
        else:
            print(f"Advertencia: La carpeta de origen '{source_species_path}' no existe. Creando destino vacío.")
            os.makedirs(destination_species_path, exist_ok=True)

# Copiar las 30 especies seleccionadas a la nueva estructura
print("Copiando especies al nuevo directorio 'train' filtrado...")
copy_species_folders(train_path_original, filtered_train_path, top_30_species)

print("Copiando especies al nuevo directorio 'test' filtrado...")
copy_species_folders(test_path_original, filtered_test_path, top_30_species)

print("Copiando especies al nuevo directorio 'valid' filtrado...")
copy_species_folders(valid_path_original, filtered_valid_path, top_30_species)

print("\nDuplicación del dataset filtrado completada.")
# Out:
# Creando la estructura de carpetas en: filtered_dataset
# Copiando especies al nuevo directorio 'train' filtrado...
# Copiado: dataset/train/MOURNING CLOAK a filtered_dataset/train/MOURNING CLOAK
# Copiado: dataset/train/GREEN HAIRSTREAK a filtered_dataset/train/GREEN HAIRSTREAK
# Copiado: dataset/train/BROWN ARGUS a filtered_dataset/train/BROWN ARGUS
# Copiado: dataset/train/BROOKES BIRDWING a filtered_dataset/train/BROOKES BIRDWING
# Copiado: dataset/train/SLEEPY ORANGE a filtered_dataset/train/SLEEPY ORANGE
# Copiado: dataset/train/CHALK HILL BLUE a filtered_dataset/train/CHALK HILL BLUE
# Copiado: dataset/train/WHITE LINED SPHINX MOTH a filtered_dataset/train/WHITE LINED SPHINX MOTH
# Copiado: dataset/train/HUMMING BIRD HAWK MOTH a filtered_dataset/train/HUMMING BIRD HAWK MOTH
# Copiado: dataset/train/ATALA a filtered_dataset/train/ATALA
# Copiado: dataset/train/BROWN SIPROETA a filtered_dataset/train/BROWN SIPROETA
# Copiado: dataset/train/ARCIGERA FLOWER MOTH a filtered_dataset/train/ARCIGERA FLOWER MOTH
# Copiado: dataset/train/SCARCE SWALLOW a filtered_dataset/train/SCARCE SWALLOW
# Copiado: dataset/train/BANDED ORANGE HELICONIAN a filtered_dataset/train/BANDED ORANGE HELICONIAN
# Copiado: dataset/train/CRECENT a filtered_dataset/train/CRECENT
# Copiado: dataset/train/MILBERTS TORTOISESHELL a filtered_dataset/train/MILBERTS TORTOISESHELL
# Copiado: dataset/train/RED CRACKER a filtered_dataset/train/RED CRACKER
# Copiado: dataset/train/ROSY MAPLE MOTH a filtered_dataset/train/ROSY MAPLE MOTH
# Copiado: dataset/train/ORANGE TIP a filtered_dataset/train/ORANGE TIP
# Copiado: dataset/train/HERCULES MOTH a filtered_dataset/train/HERCULES MOTH
# Copiado: dataset/train/BANDED TIGER MOTH a filtered_dataset/train/BANDED TIGER MOTH
# Copiado: dataset/train/Iphiclus sister a filtered_dataset/train/Iphiclus sister
# Copiado: dataset/train/EASTERN PINE ELFIN a filtered_dataset/train/EASTERN PINE ELFIN
# Copiado: dataset/train/EMPEROR GUM MOTH a filtered_dataset/train/EMPEROR GUM MOTH
# Copiado: dataset/train/CHECQUERED SKIPPER a filtered_dataset/train/CHECQUERED SKIPPER
# Copiado: dataset/train/GREAT JAY a filtered_dataset/train/GREAT JAY
# Copiado: dataset/train/DANAID EGGFLY a filtered_dataset/train/DANAID EGGFLY
# Copiado: dataset/train/COPPER TAIL a filtered_dataset/train/COPPER TAIL
# Copiado: dataset/train/EASTERN COMA a filtered_dataset/train/EASTERN COMA
# Copiado: dataset/train/BIRD CHERRY ERMINE MOTH a filtered_dataset/train/BIRD CHERRY ERMINE MOTH
# Copiado: dataset/train/CLEOPATRA a filtered_dataset/train/CLEOPATRA
# Copiando especies al nuevo directorio 'test' filtrado...
# Copiado: dataset/test/MOURNING CLOAK a filtered_dataset/test/MOURNING CLOAK
# Copiado: dataset/test/GREEN HAIRSTREAK a filtered_dataset/test/GREEN HAIRSTREAK
# Copiado: dataset/test/BROWN ARGUS a filtered_dataset/test/BROWN ARGUS
# Copiado: dataset/test/BROOKES BIRDWING a filtered_dataset/test/BROOKES BIRDWING
# Copiado: dataset/test/SLEEPY ORANGE a filtered_dataset/test/SLEEPY ORANGE
# Copiado: dataset/test/CHALK HILL BLUE a filtered_dataset/test/CHALK HILL BLUE
# Copiado: dataset/test/WHITE LINED SPHINX MOTH a filtered_dataset/test/WHITE LINED SPHINX MOTH
# Copiado: dataset/test/HUMMING BIRD HAWK MOTH a filtered_dataset/test/HUMMING BIRD HAWK MOTH
# Copiado: dataset/test/ATALA a filtered_dataset/test/ATALA
# Copiado: dataset/test/BROWN SIPROETA a filtered_dataset/test/BROWN SIPROETA
# Copiado: dataset/test/ARCIGERA FLOWER MOTH a filtered_dataset/test/ARCIGERA FLOWER MOTH
# Copiado: dataset/test/SCARCE SWALLOW a filtered_dataset/test/SCARCE SWALLOW
# Copiado: dataset/test/BANDED ORANGE HELICONIAN a filtered_dataset/test/BANDED ORANGE HELICONIAN
# Copiado: dataset/test/CRECENT a filtered_dataset/test/CRECENT
# Copiado: dataset/test/MILBERTS TORTOISESHELL a filtered_dataset/test/MILBERTS TORTOISESHELL
# Copiado: dataset/test/RED CRACKER a filtered_dataset/test/RED CRACKER
# Copiado: dataset/test/ROSY MAPLE MOTH a filtered_dataset/test/ROSY MAPLE MOTH
# Copiado: dataset/test/ORANGE TIP a filtered_dataset/test/ORANGE TIP
# Copiado: dataset/test/HERCULES MOTH a filtered_dataset/test/HERCULES MOTH
# Copiado: dataset/test/BANDED TIGER MOTH a filtered_dataset/test/BANDED TIGER MOTH
# Copiado: dataset/test/Iphiclus sister a filtered_dataset/test/Iphiclus sister
# Copiado: dataset/test/EASTERN PINE ELFIN a filtered_dataset/test/EASTERN PINE ELFIN
# Copiado: dataset/test/EMPEROR GUM MOTH a filtered_dataset/test/EMPEROR GUM MOTH
# Copiado: dataset/test/CHECQUERED SKIPPER a filtered_dataset/test/CHECQUERED SKIPPER
# Copiado: dataset/test/GREAT JAY a filtered_dataset/test/GREAT JAY
# Copiado: dataset/test/DANAID EGGFLY a filtered_dataset/test/DANAID EGGFLY
# Copiado: dataset/test/COPPER TAIL a filtered_dataset/test/COPPER TAIL
# Copiado: dataset/test/EASTERN COMA a filtered_dataset/test/EASTERN COMA
# Copiado: dataset/test/BIRD CHERRY ERMINE MOTH a filtered_dataset/test/BIRD CHERRY ERMINE MOTH
# Copiado: dataset/test/CLEOPATRA a filtered_dataset/test/CLEOPATRA
# Copiando especies al nuevo directorio 'valid' filtrado...
# Copiado: dataset/valid/MOURNING CLOAK a filtered_dataset/valid/MOURNING CLOAK
# Copiado: dataset/valid/GREEN HAIRSTREAK a filtered_dataset/valid/GREEN HAIRSTREAK
# Copiado: dataset/valid/BROWN ARGUS a filtered_dataset/valid/BROWN ARGUS
# Copiado: dataset/valid/BROOKES BIRDWING a filtered_dataset/valid/BROOKES BIRDWING
# Copiado: dataset/valid/SLEEPY ORANGE a filtered_dataset/valid/SLEEPY ORANGE
# Copiado: dataset/valid/CHALK HILL BLUE a filtered_dataset/valid/CHALK HILL BLUE
# Copiado: dataset/valid/WHITE LINED SPHINX MOTH a filtered_dataset/valid/WHITE LINED SPHINX MOTH
# Copiado: dataset/valid/HUMMING BIRD HAWK MOTH a filtered_dataset/valid/HUMMING BIRD HAWK MOTH
# Copiado: dataset/valid/ATALA a filtered_dataset/valid/ATALA
# Copiado: dataset/valid/BROWN SIPROETA a filtered_dataset/valid/BROWN SIPROETA
# Copiado: dataset/valid/ARCIGERA FLOWER MOTH a filtered_dataset/valid/ARCIGERA FLOWER MOTH
# Copiado: dataset/valid/SCARCE SWALLOW a filtered_dataset/valid/SCARCE SWALLOW
# Copiado: dataset/valid/BANDED ORANGE HELICONIAN a filtered_dataset/valid/BANDED ORANGE HELICONIAN
# Copiado: dataset/valid/CRECENT a filtered_dataset/valid/CRECENT
# Copiado: dataset/valid/MILBERTS TORTOISESHELL a filtered_dataset/valid/MILBERTS TORTOISESHELL
# Copiado: dataset/valid/RED CRACKER a filtered_dataset/valid/RED CRACKER
# Copiado: dataset/valid/ROSY MAPLE MOTH a filtered_dataset/valid/ROSY MAPLE MOTH
# Copiado: dataset/valid/ORANGE TIP a filtered_dataset/valid/ORANGE TIP
# Copiado: dataset/valid/HERCULES MOTH a filtered_dataset/valid/HERCULES MOTH
# Copiado: dataset/valid/BANDED TIGER MOTH a filtered_dataset/valid/BANDED TIGER MOTH
# Copiado: dataset/valid/Iphiclus sister a filtered_dataset/valid/Iphiclus sister
# Copiado: dataset/valid/EASTERN PINE ELFIN a filtered_dataset/valid/EASTERN PINE ELFIN
# Copiado: dataset/valid/EMPEROR GUM MOTH a filtered_dataset/valid/EMPEROR GUM MOTH
# Copiado: dataset/valid/CHECQUERED SKIPPER a filtered_dataset/valid/CHECQUERED SKIPPER
# Copiado: dataset/valid/GREAT JAY a filtered_dataset/valid/GREAT JAY
# Copiado: dataset/valid/DANAID EGGFLY a filtered_dataset/valid/DANAID EGGFLY
# Copiado: dataset/valid/COPPER TAIL a filtered_dataset/valid/COPPER TAIL
# Copiado: dataset/valid/EASTERN COMA a filtered_dataset/valid/EASTERN COMA
# Copiado: dataset/valid/BIRD CHERRY ERMINE MOTH a filtered_dataset/valid/BIRD CHERRY ERMINE MOTH
# Copiado: dataset/valid/CLEOPATRA a filtered_dataset/valid/CLEOPATRA
#
# Duplicación del dataset filtrado completada.

# %% [markdown]
# # Move 20 samples to `test` folder

# %%
num_samples_to_move = 20

print(f"\nMoviendo {num_samples_to_move} muestras de 'train' a 'test' para cada una de las 30 especies...")

for species in top_30_species:
    source_species_train_path = os.path.join(filtered_train_path, species)
    destination_species_test_path = os.path.join(filtered_test_path, species)

    # Asegurarse de que las carpetas de destino en test existan
    os.makedirs(destination_species_test_path, exist_ok=True)

    # Obtener todas las imágenes en la carpeta de la especie en train
    images_in_train = [f for f in os.listdir(source_species_train_path) if os.path.isfile(os.path.join(source_species_train_path, f))]

    # Seleccionar aleatoriamente las imágenes a mover
    if len(images_in_train) >= num_samples_to_move:
        samples_to_move = random.sample(images_in_train, num_samples_to_move)
    else:
        samples_to_move = images_in_train
        print(f"Advertencia: La especie '{species}' solo tiene {len(images_in_train)} muestras en train. Moviendo todas.")
        if len(images_in_train) == 0:
            print(f"  No hay muestras para mover para '{species}'.")
            continue

    # Mover las imágenes seleccionadas
    for img_name in samples_to_move:
        source_img_path = os.path.join(source_species_train_path, img_name)
        destination_img_path = os.path.join(destination_species_test_path, img_name)
        shutil.move(source_img_path, destination_img_path)
        print(f"  Movido: {img_name} de {species} a test.")

print(f"\nMovimiento de {num_samples_to_move} muestras por especie completado.")
# Out:
# Moviendo 20 muestras de 'train' a 'test' para cada una de las 30 especies...
#   Movido: 134.jpg de MOURNING CLOAK a test.
#   Movido: 169.jpg de MOURNING CLOAK a test.
#   Movido: 101.jpg de MOURNING CLOAK a test.
#   Movido: 074.jpg de MOURNING CLOAK a test.
#   Movido: 086.jpg de MOURNING CLOAK a test.
#   Movido: 030.jpg de MOURNING CLOAK a test.
#   Movido: 111.jpg de MOURNING CLOAK a test.
#   Movido: 040.jpg de MOURNING CLOAK a test.
#   Movido: 072.jpg de MOURNING CLOAK a test.
#   Movido: 023.jpg de MOURNING CLOAK a test.
#   Movido: 140.jpg de MOURNING CLOAK a test.
#   Movido: 172.jpg de MOURNING CLOAK a test.
#   Movido: 136.jpg de MOURNING CLOAK a test.
#   Movido: 048.jpg de MOURNING CLOAK a test.
#   Movido: 061.jpg de MOURNING CLOAK a test.
#   Movido: 064.jpg de MOURNING CLOAK a test.
#   Movido: 129.jpg de MOURNING CLOAK a test.
#   Movido: 036.jpg de MOURNING CLOAK a test.
#   Movido: 162.jpg de MOURNING CLOAK a test.
#   Movido: 173.jpg de MOURNING CLOAK a test.
#   Movido: 034.jpg de GREEN HAIRSTREAK a test.
#   Movido: 121.jpg de GREEN HAIRSTREAK a test.
#   Movido: 066.jpg de GREEN HAIRSTREAK a test.
#   Movido: 106.jpg de GREEN HAIRSTREAK a test.
#   Movido: 103.jpg de GREEN HAIRSTREAK a test.
#   Movido: 127.jpg de GREEN HAIRSTREAK a test.
#   Movido: 036.jpg de GREEN HAIRSTREAK a test.
#   Movido: 154.jpg de GREEN HAIRSTREAK a test.
#   Movido: 173.jpg de GREEN HAIRSTREAK a test.
#   Movido: 061.jpg de GREEN HAIRSTREAK a test.
#   Movido: 012.jpg de GREEN HAIRSTREAK a test.
#   Movido: 018.jpg de GREEN HAIRSTREAK a test.
#   Movido: 010.jpg de GREEN HAIRSTREAK a test.
#   Movido: 082.jpg de GREEN HAIRSTREAK a test.
#   Movido: 014.jpg de GREEN HAIRSTREAK a test.
#   Movido: 111.jpg de GREEN HAIRSTREAK a test.
#   Movido: 087.jpg de GREEN HAIRSTREAK a test.
#   Movido: 080.jpg de GREEN HAIRSTREAK a test.
#   Movido: 138.jpg de GREEN HAIRSTREAK a test.
#   Movido: 078.jpg de GREEN HAIRSTREAK a test.
#   Movido: 019.jpg de BROWN ARGUS a test.
#   Movido: 129.jpg de BROWN ARGUS a test.
#   Movido: 134.jpg de BROWN ARGUS a test.
#   Movido: 048.jpg de BROWN ARGUS a test.
#   Movido: 059.jpg de BROWN ARGUS a test.
#   Movido: 063.jpg de BROWN ARGUS a test.
#   Movido: 163.jpg de BROWN ARGUS a test.
#   Movido: 106.jpg de BROWN ARGUS a test.
#   Movido: 112.jpg de BROWN ARGUS a test.
#   Movido: 043.jpg de BROWN ARGUS a test.
#   Movido: 141.jpg de BROWN ARGUS a test.
#   Movido: 005.jpg de BROWN ARGUS a test.
#   Movido: 030.jpg de BROWN ARGUS a test.
#   Movido: 152.jpg de BROWN ARGUS a test.
#   Movido: 165.jpg de BROWN ARGUS a test.
#   Movido: 156.jpg de BROWN ARGUS a test.
#   Movido: 065.jpg de BROWN ARGUS a test.
#   Movido: 057.jpg de BROWN ARGUS a test.
#   Movido: 100.jpg de BROWN ARGUS a test.
#   Movido: 098.jpg de BROWN ARGUS a test.
#   Movido: 062.jpg de BROOKES BIRDWING a test.
#   Movido: 104.jpg de BROOKES BIRDWING a test.
#   Movido: 100.jpg de BROOKES BIRDWING a test.
#   Movido: 122.jpg de BROOKES BIRDWING a test.
#   Movido: 009.jpg de BROOKES BIRDWING a test.
#   Movido: 084.jpg de BROOKES BIRDWING a test.
#   Movido: 147.jpg de BROOKES BIRDWING a test.
#   Movido: 079.jpg de BROOKES BIRDWING a test.
#   Movido: 050.jpg de BROOKES BIRDWING a test.
#   Movido: 020.jpg de BROOKES BIRDWING a test.
#   Movido: 011.jpg de BROOKES BIRDWING a test.
#   Movido: 066.jpg de BROOKES BIRDWING a test.
#   Movido: 161.jpg de BROOKES BIRDWING a test.
#   Movido: 156.jpg de BROOKES BIRDWING a test.
#   Movido: 001.jpg de BROOKES BIRDWING a test.
#   Movido: 138.jpg de BROOKES BIRDWING a test.
#   Movido: 164.jpg de BROOKES BIRDWING a test.
#   Movido: 078.jpg de BROOKES BIRDWING a test.
#   Movido: 091.jpg de BROOKES BIRDWING a test.
#   Movido: 035.jpg de BROOKES BIRDWING a test.
#   Movido: 075.jpg de SLEEPY ORANGE a test.
#   Movido: 069.jpg de SLEEPY ORANGE a test.
#   Movido: 051.jpg de SLEEPY ORANGE a test.
#   Movido: 110.jpg de SLEEPY ORANGE a test.
#   Movido: 087.jpg de SLEEPY ORANGE a test.
#   Movido: 019.jpg de SLEEPY ORANGE a test.
#   Movido: 009.jpg de SLEEPY ORANGE a test.
#   Movido: 112.jpg de SLEEPY ORANGE a test.
#   Movido: 015.jpg de SLEEPY ORANGE a test.
#   Movido: 014.jpg de SLEEPY ORANGE a test.
#   Movido: 123.jpg de SLEEPY ORANGE a test.
#   Movido: 013.jpg de SLEEPY ORANGE a test.
#   Movido: 086.jpg de SLEEPY ORANGE a test.
#   Movido: 102.jpg de SLEEPY ORANGE a test.
#   Movido: 132.jpg de SLEEPY ORANGE a test.
#   Movido: 040.jpg de SLEEPY ORANGE a test.
#   Movido: 089.jpg de SLEEPY ORANGE a test.
#   Movido: 070.jpg de SLEEPY ORANGE a test.
#   Movido: 020.jpg de SLEEPY ORANGE a test.
#   Movido: 080.jpg de SLEEPY ORANGE a test.
#   Movido: 131.jpg de CHALK HILL BLUE a test.
#   Movido: 134.jpg de CHALK HILL BLUE a test.
#   Movido: 120.jpg de CHALK HILL BLUE a test.
#   Movido: 049.jpg de CHALK HILL BLUE a test.
#   Movido: 009.jpg de CHALK HILL BLUE a test.
#   Movido: 099.jpg de CHALK HILL BLUE a test.
#   Movido: 135.jpg de CHALK HILL BLUE a test.
#   Movido: 089.jpg de CHALK HILL BLUE a test.
#   Movido: 028.jpg de CHALK HILL BLUE a test.
#   Movido: 053.jpg de CHALK HILL BLUE a test.
#   Movido: 117.jpg de CHALK HILL BLUE a test.
#   Movido: 006.jpg de CHALK HILL BLUE a test.
#   Movido: 044.jpg de CHALK HILL BLUE a test.
#   Movido: 084.jpg de CHALK HILL BLUE a test.
#   Movido: 086.jpg de CHALK HILL BLUE a test.
#   Movido: 092.jpg de CHALK HILL BLUE a test.
#   Movido: 090.jpg de CHALK HILL BLUE a test.
#   Movido: 068.jpg de CHALK HILL BLUE a test.
#   Movido: 048.jpg de CHALK HILL BLUE a test.
#   Movido: 104.jpg de CHALK HILL BLUE a test.
#   Movido: 029.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 140.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 046.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 037.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 063.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 076.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 100.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 056.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 027.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 045.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 106.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 088.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 062.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 084.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 136.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 039.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 117.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 121.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 020.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 138.jpg de WHITE LINED SPHINX MOTH a test.
#   Movido: 019.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 135.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 113.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 026.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 107.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 131.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 134.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 090.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 089.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 055.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 025.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 071.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 066.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 048.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 049.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 073.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 121.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 132.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 023.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 095.jpg de HUMMING BIRD HAWK MOTH a test.
#   Movido: 075.jpg de ATALA a test.
#   Movido: 105.jpg de ATALA a test.
#   Movido: 046.jpg de ATALA a test.
#   Movido: 093.jpg de ATALA a test.
#   Movido: 060.jpg de ATALA a test.
#   Movido: 106.jpg de ATALA a test.
#   Movido: 073.jpg de ATALA a test.
#   Movido: 072.jpg de ATALA a test.
#   Movido: 012.jpg de ATALA a test.
#   Movido: 113.jpg de ATALA a test.
#   Movido: 080.jpg de ATALA a test.
#   Movido: 138.jpg de ATALA a test.
#   Movido: 001.jpg de ATALA a test.
#   Movido: 026.jpg de ATALA a test.
#   Movido: 095.jpg de ATALA a test.
#   Movido: 047.jpg de ATALA a test.
#   Movido: 020.jpg de ATALA a test.
#   Movido: 108.jpg de ATALA a test.
#   Movido: 048.jpg de ATALA a test.
#   Movido: 131.jpg de ATALA a test.
#   Movido: 075.jpg de BROWN SIPROETA a test.
#   Movido: 112.jpg de BROWN SIPROETA a test.
#   Movido: 058.jpg de BROWN SIPROETA a test.
#   Movido: 041.jpg de BROWN SIPROETA a test.
#   Movido: 106.jpg de BROWN SIPROETA a test.
#   Movido: 056.jpg de BROWN SIPROETA a test.
#   Movido: 137.jpg de BROWN SIPROETA a test.
#   Movido: 023.jpg de BROWN SIPROETA a test.
#   Movido: 034.jpg de BROWN SIPROETA a test.
#   Movido: 007.jpg de BROWN SIPROETA a test.
#   Movido: 066.jpg de BROWN SIPROETA a test.
#   Movido: 048.jpg de BROWN SIPROETA a test.
#   Movido: 128.jpg de BROWN SIPROETA a test.
#   Movido: 020.jpg de BROWN SIPROETA a test.
#   Movido: 097.jpg de BROWN SIPROETA a test.
#   Movido: 009.jpg de BROWN SIPROETA a test.
#   Movido: 015.jpg de BROWN SIPROETA a test.
#   Movido: 076.jpg de BROWN SIPROETA a test.
#   Movido: 086.jpg de BROWN SIPROETA a test.
#   Movido: 085.jpg de BROWN SIPROETA a test.
#   Movido: 091.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 124.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 024.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 088.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 037.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 073.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 014.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 119.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 133.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 113.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 140.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 107.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 083.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 054.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 074.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 089.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 042.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 046.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 072.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 076.jpg de ARCIGERA FLOWER MOTH a test.
#   Movido: 088.jpg de SCARCE SWALLOW a test.
#   Movido: 038.jpg de SCARCE SWALLOW a test.
#   Movido: 122.jpg de SCARCE SWALLOW a test.
#   Movido: 137.jpg de SCARCE SWALLOW a test.
#   Movido: 071.jpg de SCARCE SWALLOW a test.
#   Movido: 097.jpg de SCARCE SWALLOW a test.
#   Movido: 045.jpg de SCARCE SWALLOW a test.
#   Movido: 118.jpg de SCARCE SWALLOW a test.
#   Movido: 074.jpg de SCARCE SWALLOW a test.
#   Movido: 125.jpg de SCARCE SWALLOW a test.
#   Movido: 037.jpg de SCARCE SWALLOW a test.
#   Movido: 054.jpg de SCARCE SWALLOW a test.
#   Movido: 111.jpg de SCARCE SWALLOW a test.
#   Movido: 044.jpg de SCARCE SWALLOW a test.
#   Movido: 040.jpg de SCARCE SWALLOW a test.
#   Movido: 119.jpg de SCARCE SWALLOW a test.
#   Movido: 131.jpg de SCARCE SWALLOW a test.
#   Movido: 055.jpg de SCARCE SWALLOW a test.
#   Movido: 123.jpg de SCARCE SWALLOW a test.
#   Movido: 003.jpg de SCARCE SWALLOW a test.
#   Movido: 060.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 032.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 122.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 016.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 002.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 048.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 124.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 077.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 064.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 055.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 129.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 128.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 061.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 127.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 114.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 126.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 015.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 007.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 133.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 025.jpg de BANDED ORANGE HELICONIAN a test.
#   Movido: 10.jpg de CRECENT a test.
#   Movido: 121.jpg de CRECENT a test.
#   Movido: 71.jpg de CRECENT a test.
#   Movido: 59.jpg de CRECENT a test.
#   Movido: 125.jpg de CRECENT a test.
#   Movido: 48.jpg de CRECENT a test.
#   Movido: 38.jpg de CRECENT a test.
#   Movido: 115.jpg de CRECENT a test.
#   Movido: 14.jpg de CRECENT a test.
#   Movido: 20.jpg de CRECENT a test.
#   Movido: 29.jpg de CRECENT a test.
#   Movido: 62.jpg de CRECENT a test.
#   Movido: 36.jpg de CRECENT a test.
#   Movido: 132.jpg de CRECENT a test.
#   Movido: 73.jpg de CRECENT a test.
#   Movido: 112.jpg de CRECENT a test.
#   Movido: 138.jpg de CRECENT a test.
#   Movido: 117.jpg de CRECENT a test.
#   Movido: 47.jpg de CRECENT a test.
#   Movido: 24.jpg de CRECENT a test.
#   Movido: 026.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 004.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 124.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 035.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 110.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 084.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 120.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 105.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 099.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 060.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 122.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 037.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 042.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 045.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 077.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 109.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 049.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 126.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 067.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 078.jpg de MILBERTS TORTOISESHELL a test.
#   Movido: 033.jpg de RED CRACKER a test.
#   Movido: 133.jpg de RED CRACKER a test.
#   Movido: 115.jpg de RED CRACKER a test.
#   Movido: 132.jpg de RED CRACKER a test.
#   Movido: 019.jpg de RED CRACKER a test.
#   Movido: 046.jpg de RED CRACKER a test.
#   Movido: 091.jpg de RED CRACKER a test.
#   Movido: 066.jpg de RED CRACKER a test.
#   Movido: 063.jpg de RED CRACKER a test.
#   Movido: 135.jpg de RED CRACKER a test.
#   Movido: 004.jpg de RED CRACKER a test.
#   Movido: 023.jpg de RED CRACKER a test.
#   Movido: 073.jpg de RED CRACKER a test.
#   Movido: 110.jpg de RED CRACKER a test.
#   Movido: 121.jpg de RED CRACKER a test.
#   Movido: 054.jpg de RED CRACKER a test.
#   Movido: 131.jpg de RED CRACKER a test.
#   Movido: 061.jpg de RED CRACKER a test.
#   Movido: 058.jpg de RED CRACKER a test.
#   Movido: 057.jpg de RED CRACKER a test.
#   Movido: 122.jpg de ROSY MAPLE MOTH a test.
#   Movido: 136.jpg de ROSY MAPLE MOTH a test.
#   Movido: 058.jpg de ROSY MAPLE MOTH a test.
#   Movido: 074.jpg de ROSY MAPLE MOTH a test.
#   Movido: 135.jpg de ROSY MAPLE MOTH a test.
#   Movido: 125.jpg de ROSY MAPLE MOTH a test.
#   Movido: 116.jpg de ROSY MAPLE MOTH a test.
#   Movido: 062.jpg de ROSY MAPLE MOTH a test.
#   Movido: 112.jpg de ROSY MAPLE MOTH a test.
#   Movido: 088.jpg de ROSY MAPLE MOTH a test.
#   Movido: 100.jpg de ROSY MAPLE MOTH a test.
#   Movido: 035.jpg de ROSY MAPLE MOTH a test.
#   Movido: 002.jpg de ROSY MAPLE MOTH a test.
#   Movido: 071.jpg de ROSY MAPLE MOTH a test.
#   Movido: 082.jpg de ROSY MAPLE MOTH a test.
#   Movido: 028.jpg de ROSY MAPLE MOTH a test.
#   Movido: 121.jpg de ROSY MAPLE MOTH a test.
#   Movido: 030.jpg de ROSY MAPLE MOTH a test.
#   Movido: 107.jpg de ROSY MAPLE MOTH a test.
#   Movido: 094.jpg de ROSY MAPLE MOTH a test.
#   Movido: 71.jpg de ORANGE TIP a test.
#   Movido: 54.jpg de ORANGE TIP a test.
#   Movido: 70.jpg de ORANGE TIP a test.
#   Movido: 77.jpg de ORANGE TIP a test.
#   Movido: 37.jpg de ORANGE TIP a test.
#   Movido: 96.jpg de ORANGE TIP a test.
#   Movido: 133.jpg de ORANGE TIP a test.
#   Movido: 40.jpg de ORANGE TIP a test.
#   Movido: 58.jpg de ORANGE TIP a test.
#   Movido: 90.jpg de ORANGE TIP a test.
#   Movido: 92.jpg de ORANGE TIP a test.
#   Movido: 72.jpg de ORANGE TIP a test.
#   Movido: 76.jpg de ORANGE TIP a test.
#   Movido: 132.jpg de ORANGE TIP a test.
#   Movido: 97.jpg de ORANGE TIP a test.
#   Movido: 113.jpg de ORANGE TIP a test.
#   Movido: 85.jpg de ORANGE TIP a test.
#   Movido: 112.jpg de ORANGE TIP a test.
#   Movido: 14.jpg de ORANGE TIP a test.
#   Movido: 93.jpg de ORANGE TIP a test.
#   Movido: 049.jpg de HERCULES MOTH a test.
#   Movido: 001.jpg de HERCULES MOTH a test.
#   Movido: 132.jpg de HERCULES MOTH a test.
#   Movido: 020.jpg de HERCULES MOTH a test.
#   Movido: 128.jpg de HERCULES MOTH a test.
#   Movido: 101.jpg de HERCULES MOTH a test.
#   Movido: 012.jpg de HERCULES MOTH a test.
#   Movido: 032.jpg de HERCULES MOTH a test.
#   Movido: 085.jpg de HERCULES MOTH a test.
#   Movido: 002.jpg de HERCULES MOTH a test.
#   Movido: 047.jpg de HERCULES MOTH a test.
#   Movido: 030.jpg de HERCULES MOTH a test.
#   Movido: 113.jpg de HERCULES MOTH a test.
#   Movido: 093.jpg de HERCULES MOTH a test.
#   Movido: 135.jpg de HERCULES MOTH a test.
#   Movido: 104.jpg de HERCULES MOTH a test.
#   Movido: 064.jpg de HERCULES MOTH a test.
#   Movido: 055.jpg de HERCULES MOTH a test.
#   Movido: 068.jpg de HERCULES MOTH a test.
#   Movido: 058.jpg de HERCULES MOTH a test.
#   Movido: 070.jpg de BANDED TIGER MOTH a test.
#   Movido: 058.jpg de BANDED TIGER MOTH a test.
#   Movido: 040.jpg de BANDED TIGER MOTH a test.
#   Movido: 116.jpg de BANDED TIGER MOTH a test.
#   Movido: 069.jpg de BANDED TIGER MOTH a test.
#   Movido: 078.jpg de BANDED TIGER MOTH a test.
#   Movido: 054.jpg de BANDED TIGER MOTH a test.
#   Movido: 115.jpg de BANDED TIGER MOTH a test.
#   Movido: 062.jpg de BANDED TIGER MOTH a test.
#   Movido: 056.jpg de BANDED TIGER MOTH a test.
#   Movido: 060.jpg de BANDED TIGER MOTH a test.
#   Movido: 097.jpg de BANDED TIGER MOTH a test.
#   Movido: 108.jpg de BANDED TIGER MOTH a test.
#   Movido: 088.jpg de BANDED TIGER MOTH a test.
#   Movido: 087.jpg de BANDED TIGER MOTH a test.
#   Movido: 052.jpg de BANDED TIGER MOTH a test.
#   Movido: 130.jpg de BANDED TIGER MOTH a test.
#   Movido: 023.jpg de BANDED TIGER MOTH a test.
#   Movido: 057.jpg de BANDED TIGER MOTH a test.
#   Movido: 044.jpg de BANDED TIGER MOTH a test.
#   Movido: 135.jpg de Iphiclus sister a test.
#   Movido: 055.jpg de Iphiclus sister a test.
#   Movido: 125.jpg de Iphiclus sister a test.
#   Movido: 007.jpg de Iphiclus sister a test.
#   Movido: 022.jpg de Iphiclus sister a test.
#   Movido: 117.jpg de Iphiclus sister a test.
#   Movido: 063.jpg de Iphiclus sister a test.
#   Movido: 089.jpg de Iphiclus sister a test.
#   Movido: 101.jpg de Iphiclus sister a test.
#   Movido: 001.jpg de Iphiclus sister a test.
#   Movido: 130.jpg de Iphiclus sister a test.
#   Movido: 032.jpg de Iphiclus sister a test.
#   Movido: 012.jpg de Iphiclus sister a test.
#   Movido: 030.jpg de Iphiclus sister a test.
#   Movido: 057.jpg de Iphiclus sister a test.
#   Movido: 095.jpg de Iphiclus sister a test.
#   Movido: 111.jpg de Iphiclus sister a test.
#   Movido: 098.jpg de Iphiclus sister a test.
#   Movido: 043.jpg de Iphiclus sister a test.
#   Movido: 009.jpg de Iphiclus sister a test.
#   Movido: 037.jpg de EASTERN PINE ELFIN a test.
#   Movido: 003.jpg de EASTERN PINE ELFIN a test.
#   Movido: 024.jpg de EASTERN PINE ELFIN a test.
#   Movido: 112.jpg de EASTERN PINE ELFIN a test.
#   Movido: 125.jpg de EASTERN PINE ELFIN a test.
#   Movido: 010.jpg de EASTERN PINE ELFIN a test.
#   Movido: 098.jpg de EASTERN PINE ELFIN a test.
#   Movido: 075.jpg de EASTERN PINE ELFIN a test.
#   Movido: 031.jpg de EASTERN PINE ELFIN a test.
#   Movido: 072.jpg de EASTERN PINE ELFIN a test.
#   Movido: 059.jpg de EASTERN PINE ELFIN a test.
#   Movido: 078.jpg de EASTERN PINE ELFIN a test.
#   Movido: 055.jpg de EASTERN PINE ELFIN a test.
#   Movido: 104.jpg de EASTERN PINE ELFIN a test.
#   Movido: 022.jpg de EASTERN PINE ELFIN a test.
#   Movido: 086.jpg de EASTERN PINE ELFIN a test.
#   Movido: 088.jpg de EASTERN PINE ELFIN a test.
#   Movido: 039.jpg de EASTERN PINE ELFIN a test.
#   Movido: 118.jpg de EASTERN PINE ELFIN a test.
#   Movido: 097.jpg de EASTERN PINE ELFIN a test.
#   Movido: 034.jpg de EMPEROR GUM MOTH a test.
#   Movido: 044.jpg de EMPEROR GUM MOTH a test.
#   Movido: 043.jpg de EMPEROR GUM MOTH a test.
#   Movido: 025.jpg de EMPEROR GUM MOTH a test.
#   Movido: 069.jpg de EMPEROR GUM MOTH a test.
#   Movido: 105.jpg de EMPEROR GUM MOTH a test.
#   Movido: 107.jpg de EMPEROR GUM MOTH a test.
#   Movido: 120.jpg de EMPEROR GUM MOTH a test.
#   Movido: 045.jpg de EMPEROR GUM MOTH a test.
#   Movido: 065.jpg de EMPEROR GUM MOTH a test.
#   Movido: 119.jpg de EMPEROR GUM MOTH a test.
#   Movido: 008.jpg de EMPEROR GUM MOTH a test.
#   Movido: 091.jpg de EMPEROR GUM MOTH a test.
#   Movido: 050.jpg de EMPEROR GUM MOTH a test.
#   Movido: 110.jpg de EMPEROR GUM MOTH a test.
#   Movido: 054.jpg de EMPEROR GUM MOTH a test.
#   Movido: 077.jpg de EMPEROR GUM MOTH a test.
#   Movido: 109.jpg de EMPEROR GUM MOTH a test.
#   Movido: 049.jpg de EMPEROR GUM MOTH a test.
#   Movido: 001.jpg de EMPEROR GUM MOTH a test.
#   Movido: 120.jpg de CHECQUERED SKIPPER a test.
#   Movido: 059.jpg de CHECQUERED SKIPPER a test.
#   Movido: 034.jpg de CHECQUERED SKIPPER a test.
#   Movido: 033.jpg de CHECQUERED SKIPPER a test.
#   Movido: 009.jpg de CHECQUERED SKIPPER a test.
#   Movido: 035.jpg de CHECQUERED SKIPPER a test.
#   Movido: 020.jpg de CHECQUERED SKIPPER a test.
#   Movido: 024.jpg de CHECQUERED SKIPPER a test.
#   Movido: 016.jpg de CHECQUERED SKIPPER a test.
#   Movido: 104.jpg de CHECQUERED SKIPPER a test.
#   Movido: 042.jpg de CHECQUERED SKIPPER a test.
#   Movido: 027.jpg de CHECQUERED SKIPPER a test.
#   Movido: 078.jpg de CHECQUERED SKIPPER a test.
#   Movido: 064.jpg de CHECQUERED SKIPPER a test.
#   Movido: 058.jpg de CHECQUERED SKIPPER a test.
#   Movido: 041.jpg de CHECQUERED SKIPPER a test.
#   Movido: 037.jpg de CHECQUERED SKIPPER a test.
#   Movido: 023.jpg de CHECQUERED SKIPPER a test.
#   Movido: 109.jpg de CHECQUERED SKIPPER a test.
#   Movido: 132.jpg de CHECQUERED SKIPPER a test.
#   Movido: 038.jpg de GREAT JAY a test.
#   Movido: 046.jpg de GREAT JAY a test.
#   Movido: 112.jpg de GREAT JAY a test.
#   Movido: 030.jpg de GREAT JAY a test.
#   Movido: 111.jpg de GREAT JAY a test.
#   Movido: 017.jpg de GREAT JAY a test.
#   Movido: 048.jpg de GREAT JAY a test.
#   Movido: 008.jpg de GREAT JAY a test.
#   Movido: 058.jpg de GREAT JAY a test.
#   Movido: 024.jpg de GREAT JAY a test.
#   Movido: 093.jpg de GREAT JAY a test.
#   Movido: 088.jpg de GREAT JAY a test.
#   Movido: 075.jpg de GREAT JAY a test.
#   Movido: 122.jpg de GREAT JAY a test.
#   Movido: 005.jpg de GREAT JAY a test.
#   Movido: 053.jpg de GREAT JAY a test.
#   Movido: 067.jpg de GREAT JAY a test.
#   Movido: 087.jpg de GREAT JAY a test.
#   Movido: 018.jpg de GREAT JAY a test.
#   Movido: 090.jpg de GREAT JAY a test.
#   Movido: 129.jpg de DANAID EGGFLY a test.
#   Movido: 079.jpg de DANAID EGGFLY a test.
#   Movido: 121.jpg de DANAID EGGFLY a test.
#   Movido: 026.jpg de DANAID EGGFLY a test.
#   Movido: 099.jpg de DANAID EGGFLY a test.
#   Movido: 046.jpg de DANAID EGGFLY a test.
#   Movido: 120.jpg de DANAID EGGFLY a test.
#   Movido: 016.jpg de DANAID EGGFLY a test.
#   Movido: 019.jpg de DANAID EGGFLY a test.
#   Movido: 014.jpg de DANAID EGGFLY a test.
#   Movido: 073.jpg de DANAID EGGFLY a test.
#   Movido: 012.jpg de DANAID EGGFLY a test.
#   Movido: 083.jpg de DANAID EGGFLY a test.
#   Movido: 126.jpg de DANAID EGGFLY a test.
#   Movido: 013.jpg de DANAID EGGFLY a test.
#   Movido: 058.jpg de DANAID EGGFLY a test.
#   Movido: 045.jpg de DANAID EGGFLY a test.
#   Movido: 061.jpg de DANAID EGGFLY a test.
#   Movido: 133.jpg de DANAID EGGFLY a test.
#   Movido: 093.jpg de DANAID EGGFLY a test.
#   Movido: 122.jpg de COPPER TAIL a test.
#   Movido: 060.jpg de COPPER TAIL a test.
#   Movido: 058.jpg de COPPER TAIL a test.
#   Movido: 116.jpg de COPPER TAIL a test.
#   Movido: 025.jpg de COPPER TAIL a test.
#   Movido: 039.jpg de COPPER TAIL a test.
#   Movido: 106.jpg de COPPER TAIL a test.
#   Movido: 004.jpg de COPPER TAIL a test.
#   Movido: 117.jpg de COPPER TAIL a test.
#   Movido: 123.jpg de COPPER TAIL a test.
#   Movido: 080.jpg de COPPER TAIL a test.
#   Movido: 097.jpg de COPPER TAIL a test.
#   Movido: 035.jpg de COPPER TAIL a test.
#   Movido: 092.jpg de COPPER TAIL a test.
#   Movido: 126.jpg de COPPER TAIL a test.
#   Movido: 065.jpg de COPPER TAIL a test.
#   Movido: 071.jpg de COPPER TAIL a test.
#   Movido: 110.jpg de COPPER TAIL a test.
#   Movido: 095.jpg de COPPER TAIL a test.
#   Movido: 084.jpg de COPPER TAIL a test.
#   Movido: 48.jpg de EASTERN COMA a test.
#   Movido: 125.jpg de EASTERN COMA a test.
#   Movido: 46.jpg de EASTERN COMA a test.
#   Movido: 101.jpg de EASTERN COMA a test.
#   Movido: 132.jpg de EASTERN COMA a test.
#   Movido: 08.jpg de EASTERN COMA a test.
#   Movido: 115.jpg de EASTERN COMA a test.
#   Movido: 88.jpg de EASTERN COMA a test.
#   Movido: 57.jpg de EASTERN COMA a test.
#   Movido: 12.jpg de EASTERN COMA a test.
#   Movido: 31.jpg de EASTERN COMA a test.
#   Movido: 15.jpg de EASTERN COMA a test.
#   Movido: 32.jpg de EASTERN COMA a test.
#   Movido: 24.jpg de EASTERN COMA a test.
#   Movido: 83.jpg de EASTERN COMA a test.
#   Movido: 29.jpg de EASTERN COMA a test.
#   Movido: 117.jpg de EASTERN COMA a test.
#   Movido: 71.jpg de EASTERN COMA a test.
#   Movido: 58.jpg de EASTERN COMA a test.
#   Movido: 11.jpg de EASTERN COMA a test.
#   Movido: 083.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 034.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 073.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 128.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 061.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 046.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 099.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 042.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 125.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 051.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 119.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 103.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 078.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 080.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 049.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 044.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 001.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 071.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 085.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 070.jpg de BIRD CHERRY ERMINE MOTH a test.
#   Movido: 065.jpg de CLEOPATRA a test.
#   Movido: 126.jpg de CLEOPATRA a test.
#   Movido: 092.jpg de CLEOPATRA a test.
#   Movido: 125.jpg de CLEOPATRA a test.
#   Movido: 118.jpg de CLEOPATRA a test.
#   Movido: 053.jpg de CLEOPATRA a test.
#   Movido: 090.jpg de CLEOPATRA a test.
#   Movido: 128.jpg de CLEOPATRA a test.
#   Movido: 132.jpg de CLEOPATRA a test.
#   Movido: 037.jpg de CLEOPATRA a test.
#   Movido: 124.jpg de CLEOPATRA a test.
#   Movido: 110.jpg de CLEOPATRA a test.
#   Movido: 088.jpg de CLEOPATRA a test.
#   Movido: 127.jpg de CLEOPATRA a test.
#   Movido: 028.jpg de CLEOPATRA a test.
#   Movido: 010.jpg de CLEOPATRA a test.
#   Movido: 025.jpg de CLEOPATRA a test.
#   Movido: 070.jpg de CLEOPATRA a test.
#   Movido: 014.jpg de CLEOPATRA a test.
#   Movido: 041.jpg de CLEOPATRA a test.
#
# Movimiento de 20 muestras por especie completado.

# %%
print("\nVerificando las nuevas cantidades de muestras en 'filtered_dataset':")

def count_images_in_filtered_dataset(base_path, species_list):
    counts = defaultdict(lambda: {'train': 0, 'test': 0, 'valid': 0})
    for species in species_list:
        train_path = os.path.join(base_path, 'train', species)
        test_path = os.path.join(base_path, 'test', species)
        valid_path = os.path.join(base_path, 'valid', species)

        if os.path.exists(train_path):
            counts[species]['train'] = len([f for f in os.listdir(train_path) if os.path.isfile(os.path.join(train_path, f))])
        if os.path.exists(test_path):
            counts[species]['test'] = len([f for f in os.listdir(test_path) if os.path.isfile(os.path.join(test_path, f))])
        if os.path.exists(valid_path):
            counts[species]['valid'] = len([f for f in os.listdir(valid_path) if os.path.isfile(os.path.join(valid_path, f))])
    return counts

final_counts = count_images_in_filtered_dataset(filtered_dataset_path, top_30_species)

df_final_counts = pd.DataFrame.from_dict(final_counts, orient='index')
df_final_counts.index.name = 'Species'
df_final_counts = df_final_counts.reset_index()

print(df_final_counts)

total_train = df_final_counts['train'].sum()
total_test = df_final_counts['test'].sum()
total_valid = df_final_counts['valid'].sum()

print(f"\nTotal de imágenes en 'filtered_train': {total_train}")
print(f"Total de imágenes en 'filtered_test': {total_test}")
print(f"Total de imágenes en 'filtered_valid': {total_valid}")
print(f"Total general de imágenes en el dataset filtrado: {total_train + total_test + total_valid}")
# Out:
# Verificando las nuevas cantidades de muestras en 'filtered_dataset':
#                      Species  train  test  valid
# 0             MOURNING CLOAK    167    25      5
# 1           GREEN HAIRSTREAK    156    25      5
# 2                BROWN ARGUS    149    25      5
# 3           BROOKES BIRDWING    145    25      5
# 4              SLEEPY ORANGE    133    25      5
# 5            CHALK HILL BLUE    129    25      5
# 6    WHITE LINED SPHINX MOTH    123    25      5
# 7     HUMMING BIRD HAWK MOTH    123    25      5
# 8                      ATALA    123    25      5
# 9             BROWN SIPROETA    121    25      5
# 10      ARCIGERA FLOWER MOTH    120    25      5
# 11            SCARCE SWALLOW    119    25      5
# 12  BANDED ORANGE HELICONIAN    119    25      5
# 13                   CRECENT    118    25      5
# 14    MILBERTS TORTOISESHELL    117    25      5
# 15               RED CRACKER    117    25      5
# 16           ROSY MAPLE MOTH    117    25      5
# 17                ORANGE TIP    117    25      5
# 18             HERCULES MOTH    117    25      5
# 19         BANDED TIGER MOTH    116    25      5
# 20           Iphiclus sister    116    25      5
# 21        EASTERN PINE ELFIN    116    25      5
# 22          EMPEROR GUM MOTH    116    25      5
# 23        CHECQUERED SKIPPER    116    25      5
# 24                 GREAT JAY    115    25      5
# 25             DANAID EGGFLY    115    25      5
# 26               COPPER TAIL    114    25      5
# 27              EASTERN COMA    113    25      5
# 28   BIRD CHERRY ERMINE MOTH    113    25      5
# 29                 CLEOPATRA    113    25      5
#
# Total de imágenes en 'filtered_train': 3693
# Total de imágenes en 'filtered_test': 750
# Total de imágenes en 'filtered_valid': 150
# Total general de imágenes en el dataset filtrado: 4593

# %%
print("\nGenerando el archivo CSV con los metadatos del dataset filtrado...")

# Definir la ruta donde se guardará el CSV
csv_output_path = os.path.join(filtered_dataset_path, 'filtered_dataset_metadata.csv')

# Crear un diccionario para mapear el nombre de la especie a un índice numérico
species_to_index = {species: i for i, species in enumerate(top_30_species)}

data = []

# Recorrer los conjuntos (train, test, valid)
for dataset_type in ['train', 'test', 'valid']:
    current_dataset_path = os.path.join(filtered_dataset_path, dataset_type)

    # Recorrer cada especie dentro del conjunto actual
    for species_name in os.listdir(current_dataset_path):
        species_folder_path = os.path.join(current_dataset_path, species_name)

        if os.path.isdir(species_folder_path) and species_name in species_to_index:
            class_index = species_to_index[species_name]

            # Recorrer cada imagen en la carpeta de la especie
            for image_name in os.listdir(species_folder_path):
                image_path = os.path.join(species_folder_path, image_name)

                if os.path.isfile(image_path):
                    # 'filtered_dataset_path' es la base de referencia para las rutas relativas.
                    relative_filepath = os.path.relpath(image_path, start=filtered_dataset_path)

                    data.append({
                        'class_index': class_index,
                        'filepaths': relative_filepath,
                        'labels': species_name,
                        'data_set': dataset_type
                    })

# Crear un DataFrame de pandas
df_metadata = pd.DataFrame(data)

# Guardar el DataFrame en un archivo CSV
df_metadata.to_csv(csv_output_path, index=False)

print(f"\nCSV de metadatos generado exitosamente en: {csv_output_path}")
print("\nLas primeras 5 filas del CSV (con rutas relativas):")
print(df_metadata.head())
print(f"\nTotal de filas en el CSV: {len(df_metadata)}")

# Opcional: Verificar la distribución de los datasets en el CSV
print("\nDistribución de imágenes por conjunto en el CSV:")
print(df_metadata['data_set'].value_counts())
# Out:
# Generando el archivo CSV con los metadatos del dataset filtrado...
#
# CSV de metadatos generado exitosamente en: filtered_dataset/filtered_dataset_metadata.csv
#
# Las primeras 5 filas del CSV (con rutas relativas):
#    class_index                  filepaths       labels data_set
# 0           15  train/RED CRACKER/016.jpg  RED CRACKER    train
# 1           15  train/RED CRACKER/002.jpg  RED CRACKER    train
# 2           15  train/RED CRACKER/003.jpg  RED CRACKER    train
# 3           15  train/RED CRACKER/017.jpg  RED CRACKER    train
# 4           15  train/RED CRACKER/029.jpg  RED CRACKER    train
#
# Total de filas en el CSV: 4593
#
# Distribución de imágenes por conjunto en el CSV:
# data_set
# train    3693
# test      750
# valid     150
# Name: count, dtype: int64
