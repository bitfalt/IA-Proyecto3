# %% [markdown]
# # Experimento 2: Denoising Autoencoder y Visualización del Espacio Latente
#
# Este notebook implementa el Experimento 2 del proyecto:
# 1. **Denoising Autoencoder**: Autoencoder que elimina ruido Salt and Pepper
# 2. **Visualización del Espacio Latente**: Uso de t-SNE para visualizar representaciones latentes
# 3. **Clustering K-means**: Agrupación no supervisada de vectores latentes
# 4. **Análisis de Clusters**: Comparación de imágenes por cluster
#
# ## Objetivos:
# - Entrenar un Denoising Autoencoder con ruido Salt and Pepper
# - Extraer vectores latentes del conjunto sin etiquetas
# - Visualizar vectores latentes con t-SNE
# - Aplicar clustering K-means a los vectores latentes
# - Analizar coherencia de clusters comparando imágenes
#
# ## Optimizaciones para GPU implementadas:
# - ✅ Configuración automática de acelerador (`accelerator='auto'`)
# - ✅ Detección automática de dispositivos (`devices='auto'`)
# - ✅ Precisión mixta habilitada para GPU (`precision='16-mixed'`)
# - ✅ Batch size adaptativo según memoria GPU disponible
# - ✅ Optimizaciones cuDNN habilitadas
# - ✅ Manejo correcto de dispositivos en evaluación
# - ✅ Verificación completa de configuración GPU

# %%
# Imports básicos
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
import torchmetrics
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
import wandb
import os
import warnings
from PIL import Image
import random
from collections import defaultdict
warnings.filterwarnings('ignore')

# Importar nuestros módulos de carga de datos
from dataset import ButterflyDataset, get_transforms
from datamodule import ButterflyDataModule

# Configurar dispositivo y mostrar información detallada
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Información adicional sobre GPU si está disponible
if torch.cuda.is_available():
    print(f'GPU disponible: {torch.cuda.get_device_name(0)}')
    print(f'Memoria GPU total: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB')
    print(f'Versión CUDA: {torch.version.cuda}')
    print(f'cuDNN habilitado: {torch.backends.cudnn.enabled}')
    print(f'Precisión mixta disponible: {torch.cuda.is_available() and hasattr(torch.cuda, "amp")}')
    
    # Limpiar caché de GPU
    torch.cuda.empty_cache()
else:
    print('GPU no disponible, usando CPU')
    print('Nota: El entrenamiento será significativamente más lento en CPU')

print(f'PyTorch version: {torch.__version__}')
print(f'PyTorch Lightning version: {pl.__version__}')
# Out:
# Using device: cuda
# GPU disponible: NVIDIA GeForce RTX 3070
# Memoria GPU total: 8.0 GB
# Versión CUDA: 12.1
# cuDNN habilitado: True
# Precisión mixta disponible: True
# PyTorch version: 2.5.1+cu121
# PyTorch Lightning version: 2.5.1.post0

# %%
# Configuración del proyecto
DATA_DIR = "filtered_dataset/train"
METADATA_CSV = "filtered_dataset/filtered_dataset_metadata.csv"

# Ajustar batch size según disponibilidad de GPU
if torch.cuda.is_available():
    # GPU disponible - usar batch size más grande si hay suficiente memoria
    gpu_memory_gb = torch.cuda.get_device_properties(0).total_memory / 1024**3
    if gpu_memory_gb >= 8:
        BATCH_SIZE = 64  # Para GPUs con 8GB+ de memoria
    elif gpu_memory_gb >= 4:
        BATCH_SIZE = 32  # Para GPUs con 4-8GB de memoria
    else:
        BATCH_SIZE = 16  # Para GPUs con menos de 4GB
    print(f'Batch size ajustado para GPU: {BATCH_SIZE}')
else:
    BATCH_SIZE = 16  # Batch size más pequeño para CPU
    print(f'Batch size ajustado para CPU: {BATCH_SIZE}')

IMAGE_SIZE = 224
NUM_EPOCHS = 50
LEARNING_RATE = 1e-3
SEED = 42

# Parámetros específicos del experimento 2
NOISE_PROBABILITY = 0.05  # Probabilidad de ruido Salt and Pepper
NUM_CLUSTERS = 30  # Número de clusters para K-means (igual al número de clases)
TSNE_PERPLEXITY = 30  # Parámetro de perplexity para t-SNE
TSNE_N_ITER = 1000  # Número de iteraciones para t-SNE

# Configurar semilla para reproducibilidad
pl.seed_everything(SEED)

# Optimizaciones para GPU si está disponible
if torch.cuda.is_available():
    # Habilitar optimizaciones de cuDNN
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = False  # Para mejor rendimiento
    print("Optimizaciones de cuDNN habilitadas")

# Configurar Wandb
wandb.init(
    project="butterfly-denoising-autoencoder",
    name="experiment_2_denoising_tsne_clustering",
    config={
        "batch_size": BATCH_SIZE,
        "image_size": IMAGE_SIZE,
        "num_epochs": NUM_EPOCHS,
        "learning_rate": LEARNING_RATE,
        "seed": SEED,
        "noise_probability": NOISE_PROBABILITY,
        "num_clusters": NUM_CLUSTERS,
        "tsne_perplexity": TSNE_PERPLEXITY,
        "tsne_n_iter": TSNE_N_ITER
    }
)
# Out:
# Seed set to 42
# Batch size ajustado para GPU: 32
# Optimizaciones de cuDNN habilitadas
# wandb: Currently logged in as: jpablix (bitfalt-itcr) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>m:\Projects\IA-Proyecto3\wandb\run-20250622_225135-le5o4vwk</code>
# Syncing run <strong><a href='https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder/runs/le5o4vwk' target="_blank">experiment_2_denoising_tsne_clustering</a></strong> to <a href='https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder' target="_blank">https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder</a>
#  View run at <a href='https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder/runs/le5o4vwk' target="_blank">https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder/runs/le5o4vwk</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder/runs/le5o4vwk?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# Reutilizar configuración del experimento 1 (70% no etiquetado, 30% etiquetado)
# Según el enunciado, reutilizamos uno de los cortes de datos del Experimento 1

data_module_70_30 = ButterflyDataModule(
    data_dir=DATA_DIR,
    metadata_csv=METADATA_CSV,
    batch_size=BATCH_SIZE,
    num_workers=4,
    image_size=IMAGE_SIZE,
    labeled_ratio=0.3,  # 30% etiquetado, 70% no etiquetado (igual que experimento 1)
    seed=SEED
)

# Configurar datasets
data_module_70_30.setup()
print("Información del dataset 70-30 (reutilizado del Experimento 1):")
info = data_module_70_30.get_dataset_info()
for key, value in info.items():
    print(f"{key}: {value}")

print(f"\nDataset configurado para Experimento 2:")
print(f"- Datos no etiquetados para entrenamiento: {info['unlabeled_size']}")
print(f"- Datos de validación: {info['val_size']}")
print(f"- Datos de test: {info['test_size']}")
print(f"- Número de clases: {info['num_classes']}")
# Out:
# Found 3693 images across 30 classes
# Classes: ['ARCIGERA FLOWER MOTH', 'ATALA', 'BANDED ORANGE HELICONIAN', 'BANDED TIGER MOTH', 'BIRD CHERRY ERMINE MOTH', 'BROOKES BIRDWING', 'BROWN ARGUS', 'BROWN SIPROETA', 'CHALK HILL BLUE', 'CHECQUERED SKIPPER', 'CLEOPATRA', 'COPPER TAIL', 'CRECENT', 'DANAID EGGFLY', 'EASTERN COMA', 'EASTERN PINE ELFIN', 'EMPEROR GUM MOTH', 'GREAT JAY', 'GREEN HAIRSTREAK', 'HERCULES MOTH', 'HUMMING BIRD HAWK MOTH', 'Iphiclus sister', 'MILBERTS TORTOISESHELL', 'MOURNING CLOAK', 'ORANGE TIP', 'RED CRACKER', 'ROSY MAPLE MOTH', 'SCARCE SWALLOW', 'SLEEPY ORANGE', 'WHITE LINED SPHINX MOTH']
# Dataset splits - Train: 2584, Val: 739, Test: 370
# Semi-supervised split - Labeled: 775, Unlabeled: 1809
# Información del dataset 70-30 (reutilizado del Experimento 1):
# num_classes: 30
# class_names: ['ARCIGERA FLOWER MOTH', 'ATALA', 'BANDED ORANGE HELICONIAN', 'BANDED TIGER MOTH', 'BIRD CHERRY ERMINE MOTH', 'BROOKES BIRDWING', 'BROWN ARGUS', 'BROWN SIPROETA', 'CHALK HILL BLUE', 'CHECQUERED SKIPPER', 'CLEOPATRA', 'COPPER TAIL', 'CRECENT', 'DANAID EGGFLY', 'EASTERN COMA', 'EASTERN PINE ELFIN', 'EMPEROR GUM MOTH', 'GREAT JAY', 'GREEN HAIRSTREAK', 'HERCULES MOTH', 'HUMMING BIRD HAWK MOTH', 'Iphiclus sister', 'MILBERTS TORTOISESHELL', 'MOURNING CLOAK', 'ORANGE TIP', 'RED CRACKER', 'ROSY MAPLE MOTH', 'SCARCE SWALLOW', 'SLEEPY ORANGE', 'WHITE LINED SPHINX MOTH']
# batch_size: 32
# image_size: 224
# labeled_ratio: 0.3
# train_size: 2584
# val_size: 739
# test_size: 370
# labeled_size: 775
# unlabeled_size: 1809
#
# Dataset configurado para Experimento 2:
# - Datos no etiquetados para entrenamiento: 1809
# - Datos de validación: 739
# - Datos de test: 370
# - Número de clases: 30

# %% [markdown]
# ## Función de Ruido Salt and Pepper
#
# Implementamos la función para agregar ruido Salt and Pepper a las imágenes, como se especifica en el enunciado.

# %%
def add_salt_and_pepper_noise(image, noise_prob=0.05):
    """
    Agrega ruido Salt and Pepper a una imagen.
    
    Args:
        image: Tensor de imagen [C, H, W] con valores en [0, 1]
        noise_prob: Probabilidad de ruido (mitad salt, mitad pepper)
    
    Returns:
        Imagen con ruido Salt and Pepper
    """
    noisy_image = image.clone()
    
    # Generar máscara de ruido
    noise_mask = torch.rand_like(image[0]) < noise_prob
    
    # Salt and Pepper: mitad de los píxeles ruidosos se vuelven blancos (1), mitad negros (0)
    salt_mask = torch.rand_like(image[0]) < 0.5
    pepper_mask = ~salt_mask
    
    # Aplicar ruido salt (blanco) y pepper (negro)
    for c in range(image.shape[0]):
        noisy_image[c][noise_mask & salt_mask] = 1.0    # Salt (blanco)
        noisy_image[c][noise_mask & pepper_mask] = 0.0  # Pepper (negro)
    
    return noisy_image

def visualize_noise_effect(original, noisy, title="Salt and Pepper Noise Effect"):
    """Visualiza el efecto del ruido en una imagen"""
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
    # Imagen original
    if original.dim() == 3:
        original_np = original.permute(1, 2, 0).cpu().numpy()
    else:
        original_np = original.cpu().numpy()
    axes[0].imshow(original_np)
    axes[0].set_title("Imagen Original")
    axes[0].axis('off')
    
    # Imagen con ruido
    if noisy.dim() == 3:
        noisy_np = noisy.permute(1, 2, 0).cpu().numpy()
    else:
        noisy_np = noisy.cpu().numpy()
    axes[1].imshow(noisy_np)
    axes[1].set_title("Imagen con Ruido Salt & Pepper")
    axes[1].axis('off')
    
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# Prueba de la función de ruido
print("Función de ruido Salt and Pepper definida")
print(f"Probabilidad de ruido configurada: {NOISE_PROBABILITY}")
# Out:
# Función de ruido Salt and Pepper definida
# Probabilidad de ruido configurada: 0.05

# %% [markdown]
# ## Arquitectura del Denoising Autoencoder
#
# Reutilizamos la arquitectura U-Net del Experimento 1, pero adaptada para denoising. El modelo toma imágenes con ruido como entrada y las reconstruye sin ruido.

# %%
# Reutilizar arquitectura U-Net del Experimento 1
class DoubleConv(nn.Module):
    """Doble convolución: (conv => BN => ReLU) * 2"""
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling con maxpool y double conv"""
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling con transpose conv y double conv"""
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # Skip connection - OBLIGATORIA según especificaciones
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]
        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        x = torch.cat([x2, x1], dim=1)  # Skip connection
        return self.conv(x)

# %%
class DenoisingUNetAutoencoder(pl.LightningModule):
    """
    Denoising U-Net Autoencoder con skip connections.
    Entrenado para eliminar ruido Salt and Pepper de las imágenes.
    """
    def __init__(self, n_channels=3, learning_rate=1e-3, noise_prob=0.05):
        super().__init__()
        self.learning_rate = learning_rate
        self.noise_prob = noise_prob
        self.save_hyperparameters()
        
        # Encoder (Contracting path)
        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        self.down4 = Down(512, 1024)
        
        # Decoder (Expansive path)
        self.up1 = Up(1024, 512)
        self.up2 = Up(512, 256)
        self.up3 = Up(256, 128)
        self.up4 = Up(128, 64)
        self.outc = nn.Conv2d(64, n_channels, kernel_size=1)
        
        # Para extraer features del encoder (espacio latente)
        self.encoder_features = None
        
        # Métricas
        self.train_psnr = torchmetrics.PeakSignalNoiseRatio()
        self.val_psnr = torchmetrics.PeakSignalNoiseRatio()
        self.train_ssim = torchmetrics.StructuralSimilarityIndexMeasure()
        self.val_ssim = torchmetrics.StructuralSimilarityIndexMeasure()
    
    def forward(self, x):
        # Encoder
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        
        # Guardar features del encoder (espacio latente)
        self.encoder_features = x5
        
        # Decoder con skip connections
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        
        return torch.sigmoid(logits)  # Salida entre 0 y 1
    
    def get_encoder_features(self, x):
        """Extrae features del encoder (representación latente)"""
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        return x5
    
    def training_step(self, batch, batch_idx):
        if isinstance(batch, (list, tuple)):
            x_clean = batch[0]  # Get only images, ignore labels
        else:
            x_clean = batch
        
        # Agregar ruido Salt and Pepper
        x_noisy = torch.stack([
            add_salt_and_pepper_noise(img, self.noise_prob) 
            for img in x_clean
        ])
        
        # Forward pass: imagen ruidosa -> imagen limpia
        x_reconstructed = self(x_noisy)
        
        # Calcular pérdidas
        mse_loss = F.mse_loss(x_reconstructed, x_clean)
        l1_loss = F.l1_loss(x_reconstructed, x_clean)
        total_loss = mse_loss + 0.1 * l1_loss  # Combinar MSE y L1
        
        # Métricas
        psnr = self.train_psnr(x_reconstructed, x_clean)
        ssim = self.train_ssim(x_reconstructed, x_clean)
        
        # Logging
        self.log('train_loss', total_loss, prog_bar=True)
        self.log('train_mse_loss', mse_loss)
        self.log('train_l1_loss', l1_loss)
        self.log('train_psnr', psnr, prog_bar=True)
        self.log('train_ssim', ssim)
        
        # Log a Wandb
        wandb.log({
            'train_denoising_loss': total_loss,
            'train_denoising_mse': mse_loss,
            'train_denoising_l1': l1_loss,
            'train_denoising_psnr': psnr,
            'train_denoising_ssim': ssim
        })
        
        return total_loss
    
    def validation_step(self, batch, batch_idx):
        if isinstance(batch, (list, tuple)):
            x_clean = batch[0]  # Get only images, ignore labels
        else:
            x_clean = batch
        
        # Agregar ruido Salt and Pepper
        x_noisy = torch.stack([
            add_salt_and_pepper_noise(img, self.noise_prob) 
            for img in x_clean
        ])
        
        # Forward pass
        x_reconstructed = self(x_noisy)
        
        # Calcular pérdidas
        mse_loss = F.mse_loss(x_reconstructed, x_clean)
        l1_loss = F.l1_loss(x_reconstructed, x_clean)
        total_loss = mse_loss + 0.1 * l1_loss
        
        # Métricas
        psnr = self.val_psnr(x_reconstructed, x_clean)
        ssim = self.val_ssim(x_reconstructed, x_clean)
        
        # Logging
        self.log('val_loss', total_loss, prog_bar=True)
        self.log('val_mse_loss', mse_loss)
        self.log('val_l1_loss', l1_loss)
        self.log('val_psnr', psnr, prog_bar=True)
        self.log('val_ssim', ssim)
        
        # Log a Wandb
        wandb.log({
            'val_denoising_loss': total_loss,
            'val_denoising_mse': mse_loss,
            'val_denoising_l1': l1_loss,
            'val_denoising_psnr': psnr,
            'val_denoising_ssim': ssim
        })
        
        # Guardar ejemplos de reconstrucción para visualización (solo cada 10 epochs para evitar spam)
        if batch_idx == 0 and self.current_epoch % 10 == 0:
            self.log_reconstruction_examples(x_clean[:4], x_noisy[:4], x_reconstructed[:4])
        
        return total_loss
    
    def log_reconstruction_examples(self, clean, noisy, reconstructed):
        """Log ejemplos de reconstrucción a Wandb"""
        try:
            fig, axes = plt.subplots(3, 4, figsize=(16, 12))
            
            for i in range(4):
                # Imagen limpia original
                clean_img = clean[i].detach().permute(1, 2, 0).cpu().numpy().astype(np.float32)
                clean_img = np.clip(clean_img, 0, 1)  # Asegurar rango [0,1]
                axes[0, i].imshow(clean_img)
                axes[0, i].set_title(f'Original {i+1}')
                axes[0, i].axis('off')
                
                # Imagen con ruido
                noisy_img = noisy[i].detach().permute(1, 2, 0).cpu().numpy().astype(np.float32)
                noisy_img = np.clip(noisy_img, 0, 1)  # Asegurar rango [0,1]
                axes[1, i].imshow(noisy_img)
                axes[1, i].set_title(f'Ruidosa {i+1}')
                axes[1, i].axis('off')
                
                # Imagen reconstruida
                recon_img = reconstructed[i].detach().permute(1, 2, 0).cpu().numpy().astype(np.float32)
                recon_img = np.clip(recon_img, 0, 1)  # Asegurar rango [0,1]
                axes[2, i].imshow(recon_img)
                axes[2, i].set_title(f'Reconstruida {i+1}')
                axes[2, i].axis('off')
            
            plt.suptitle('Ejemplos de Denoising con Salt and Pepper Noise')
            plt.tight_layout()
            
            # Log a Wandb sin mostrar la figura para evitar errores
            wandb.log({"denoising_examples": wandb.Image(fig)})
            plt.close(fig)
            
        except Exception as e:
            print(f"Error en visualización de ejemplos (no crítico): {e}")
            # No hacer nada más para evitar interrumpir el entrenamiento
    
    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='min', factor=0.5, patience=5
        )
        return {
            'optimizer': optimizer,
            'lr_scheduler': scheduler,
            'monitor': 'val_loss'
        }

# %% [markdown]
# ## Funciones de Entrenamiento y Evaluación

# %%
def train_denoising_autoencoder(data_module, max_epochs=30):
    """Entrena el Denoising Autoencoder U-Net"""
    print("=== Entrenando Denoising Autoencoder U-Net ===")
    
    # Crear modelo
    denoising_autoencoder = DenoisingUNetAutoencoder(
        learning_rate=LEARNING_RATE,
        noise_prob=NOISE_PROBABILITY
    )
    
    # Callbacks
    callbacks = [
        pl.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=10,
            mode='min'
        ),
        pl.callbacks.ModelCheckpoint(
            monitor='val_loss',
            mode='min',
            save_top_k=1,
            filename='denoising-autoencoder-{epoch:02d}-{val_loss:.2f}'
        )
    ]
    
    # Trainer - Configuración automática de GPU
    trainer = pl.Trainer(
        max_epochs=max_epochs,
        callbacks=callbacks,
        accelerator='auto',
        devices='auto',
        log_every_n_steps=10,
        precision='16-mixed' if torch.cuda.is_available() else '32'
    )
    
    # Entrenar usando datos no etiquetados
    trainer.fit(
        model=denoising_autoencoder,
        train_dataloaders=data_module.unlabeled_dataloader(),
        val_dataloaders=data_module.val_dataloader()
    )
    
    return denoising_autoencoder


def evaluate_denoising_performance(model, data_module):
    """Evalúa el rendimiento del denoising autoencoder"""
    print("=== Evaluando Rendimiento de Denoising ===")
    
    model.eval()
    device = next(model.parameters()).device
    
    total_mse = 0
    total_psnr = 0
    total_ssim = 0
    num_batches = 0
    
    # Métricas
    psnr_metric = torchmetrics.PeakSignalNoiseRatio().to(device)
    ssim_metric = torchmetrics.StructuralSimilarityIndexMeasure().to(device)
    
    with torch.no_grad():
        for batch_idx, batch in enumerate(data_module.test_dataloader()):
            try:
                if isinstance(batch, (list, tuple)):
                    x_clean = batch[0].to(device)
                else:
                    x_clean = batch.to(device)
                
                # Agregar ruido
                x_noisy = torch.stack([
                    add_salt_and_pepper_noise(img, model.noise_prob) 
                    for img in x_clean
                ]).to(device)
                
                # Reconstruir
                x_reconstructed = model(x_noisy)
                
                # Asegurar que todos los tensores estén en el rango correcto [0, 1]
                x_clean = torch.clamp(x_clean, 0, 1)
                x_reconstructed = torch.clamp(x_reconstructed, 0, 1)
                
                # Calcular métricas
                mse = F.mse_loss(x_reconstructed, x_clean)
                psnr = psnr_metric(x_reconstructed, x_clean)
                ssim = ssim_metric(x_reconstructed, x_clean)
                
                total_mse += mse.item()
                total_psnr += psnr.item()
                total_ssim += ssim.item()
                num_batches += 1
                
                # Mostrar progreso cada 10 batches sin imágenes para evitar errores
                if batch_idx % 10 == 0:
                    print(f"Evaluando batch {batch_idx + 1}...")
                    
            except Exception as e:
                print(f"Error en batch {batch_idx}: {e}")
                continue
    
    # Promedios
    if num_batches > 0:
        avg_mse = total_mse / num_batches
        avg_psnr = total_psnr / num_batches
        avg_ssim = total_ssim / num_batches
    else:
        print("Error: No se pudieron procesar batches")
        return {'test_mse': 0, 'test_psnr': 0, 'test_ssim': 0}
    
    results = {
        'test_mse': avg_mse,
        'test_psnr': avg_psnr,
        'test_ssim': avg_ssim
    }
    
    # Log a Wandb
    wandb.log({
        'test_denoising_mse': avg_mse,
        'test_denoising_psnr': avg_psnr,
        'test_denoising_ssim': avg_ssim
    })
    
    print(f"Resultados de evaluación:")
    print(f"MSE: {avg_mse:.6f}")
    print(f"PSNR: {avg_psnr:.2f} dB")
    print(f"SSIM: {avg_ssim:.4f}")
    
    return results

# %% [markdown]
# ## Demostración del Ruido Salt and Pepper
#
# Primero demostramos el efecto del ruido Salt and Pepper en las imágenes según el enunciado.

# %%
# Demostrar el efecto del ruido Salt and Pepper según el enunciado
print("=== DEMOSTRACIÓN DEL RUIDO SALT AND PEPPER ===")
print("Según el enunciado, se debe agregar 'Salt and Pepper Noise' a las imágenes")
print(f"Probabilidad de ruido configurada: {NOISE_PROBABILITY}")

# Obtener algunas imágenes de muestra para demostración
sample_batch = next(iter(data_module_70_30.val_dataloader()))
sample_images, sample_labels = sample_batch

# Aplicar ruido Salt and Pepper a las imágenes de muestra
print(f"\nAplicando ruido Salt and Pepper a {len(sample_images)} imágenes de muestra...")
noisy_images = torch.stack([
    add_salt_and_pepper_noise(img, NOISE_PROBABILITY) 
    for img in sample_images[:4]
])

# Visualizar el efecto del ruido
try:
    fig, axes = plt.subplots(2, 4, figsize=(16, 8))

    for i in range(4):
        # Imagen original
        original_img = sample_images[i].detach().permute(1, 2, 0).cpu().numpy().astype(np.float32)
        original_img = np.clip(original_img, 0, 1)
        axes[0, i].imshow(original_img)
        axes[0, i].set_title(f'Original {i+1}')
        axes[0, i].axis('off')
        
        # Imagen con ruido Salt and Pepper
        noisy_img = noisy_images[i].detach().permute(1, 2, 0).cpu().numpy().astype(np.float32)
        noisy_img = np.clip(noisy_img, 0, 1)
        axes[1, i].imshow(noisy_img)
        axes[1, i].set_title(f'Con Salt & Pepper Noise {i+1}')
        axes[1, i].axis('off')

    plt.suptitle(f'Efecto del Salt and Pepper Noise (Probabilidad: {NOISE_PROBABILITY})')
    plt.tight_layout()
    wandb.log({"salt_pepper_noise_demo": wandb.Image(fig)})
    plt.close(fig)  # Cerrar figura inmediatamente
    
except Exception as e:
    print(f"Error en visualización de ruido (no crítico): {e}")

print("✅ Demostración del ruido Salt and Pepper completada")
print("📸 Las imágenes muestran píxeles blancos (salt) y negros (pepper) agregados aleatoriamente")
# Out:
# === DEMOSTRACIÓN DEL RUIDO SALT AND PEPPER ===
# Según el enunciado, se debe agregar 'Salt and Pepper Noise' a las imágenes
# Probabilidad de ruido configurada: 0.05
#
# Aplicando ruido Salt and Pepper a 32 imágenes de muestra...
# ✅ Demostración del ruido Salt and Pepper completada
# 📸 Las imágenes muestran píxeles blancos (salt) y negros (pepper) agregados aleatoriamente

# %% [markdown]
# ## Entrenamiento del Denoising Autoencoder
#
# Ahora entrenamos el Denoising Autoencoder que aprenderá a eliminar el ruido Salt and Pepper de las imágenes.

# %%
# Entrenar el Denoising Autoencoder
print("=== ENTRENANDO DENOISING AUTOENCODER ===")
print("Iniciando entrenamiento del Denoising Autoencoder...")
print(f"Configuración:")
print(f"- Probabilidad de ruido Salt & Pepper: {NOISE_PROBABILITY}")
print(f"- Épocas máximas: {NUM_EPOCHS}")
print(f"- Learning rate: {LEARNING_RATE}")
print(f"- Batch size: {BATCH_SIZE}")
print(f"- Arquitectura: U-Net con skip connections")
print(f"- Objetivo: Eliminar ruido Salt and Pepper de las imágenes")

denoising_autoencoder = train_denoising_autoencoder(data_module_70_30, max_epochs=NUM_EPOCHS)

print("\n✅ Denoising Autoencoder entrenado exitosamente!")

# Evaluar rendimiento del denoising
print("\n=== EVALUANDO RENDIMIENTO DEL DENOISING ===")
denoising_results = evaluate_denoising_performance(denoising_autoencoder, data_module_70_30)
# Out:
# === ENTRENANDO DENOISING AUTOENCODER ===
# Iniciando entrenamiento del Denoising Autoencoder...
# Configuración:
# - Probabilidad de ruido Salt & Pepper: 0.05
# - Épocas máximas: 50
# - Learning rate: 0.001
# - Batch size: 32
# - Arquitectura: U-Net con skip connections
# - Objetivo: Eliminar ruido Salt and Pepper de las imágenes
# === Entrenando Denoising Autoencoder U-Net ===
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3070') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name       | Type                              | Params | Mode
# --------------------------------------------------------------------------
# 0  | inc        | DoubleConv                        | 39.0 K | train
# 1  | down1      | Down                              | 221 K  | train
# 2  | down2      | Down                              | 886 K  | train
# 3  | down3      | Down                              | 3.5 M  | train
# 4  | down4      | Down                              | 14.2 M | train
# 5  | up1        | Up                                | 9.2 M  | train
# 6  | up2        | Up                                | 2.3 M  | train
# 7  | up3        | Up                                | 574 K  | train
# 8  | up4        | Up                                | 143 K  | train
# 9  | outc       | Conv2d                            | 195    | train
# 10 | train_psnr | _PeakSignalNoiseRatio             | 0      | train
# 11 | val_psnr   | _PeakSignalNoiseRatio             | 0      | train
# 12 | train_ssim | _StructuralSimilarityIndexMeasure | 0      | train
# 13 | val_ssim   | _StructuralSimilarityIndexMeasure | 0      | train
# --------------------------------------------------------------------------
# 31.0 M    Trainable params
# 0         Non-trainable params
# 31.0 M    Total params
# 124.175   Total estimated model params size (MB)
# 97        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 57/57 [00:50<00:00,  1.13it/s, v_num=28, train_loss=1.340, train_psnr=12.60]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:01<00:40,  0.57it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:01<00:20,  1.05it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:02<00:14,  1.47it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:02<00:11,  1.81it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:02<00:08,  2.12it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:02<00:07,  2.38it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:02<00:06,  2.62it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:02<00:05,  2.82it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:02<00:04,  3.01it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:03<00:04,  3.17it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:03<00:03,  3.32it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:03<00:03,  3.46it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:03<00:03,  3.59it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:03<00:02,  3.71it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:03<00:02,  3.82it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:04<00:02,  3.92it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:04<00:01,  4.01it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:04<00:01,  4.11it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:04<00:01,  4.19it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:04<00:00,  4.27it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:04<00:00,  4.34it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:04<00:00,  4.41it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:05<00:00,  4.47it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:05<00:00,  4.31it/s]
# Epoch 1: 100%|██████████| 57/57 [00:22<00:00,  2.50it/s, v_num=28, train_loss=1.340, train_psnr=12.60, val_loss=1.050, val_psnr=13.70]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.07it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.31it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.38it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.32it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:02,  6.36it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.37it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.37it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.40it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.39it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.41it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.42it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.43it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.44it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.46it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.45it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.45it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.47it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.48it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:02<00:00,  6.48it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.48it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.49it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.49it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.50it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.74it/s]
# Epoch 2: 100%|██████████| 57/57 [00:23<00:00,  2.47it/s, v_num=28, train_loss=1.490, train_psnr=12.10, val_loss=0.966, val_psnr=14.10]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.99it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  5.95it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.16it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.15it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.26it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.29it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.33it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.35it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.35it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.37it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.36it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.36it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.36it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.35it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.36it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:02<00:00,  6.36it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.33it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.36it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.37it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.60it/s]
# Epoch 3: 100%|██████████| 57/57 [00:23<00:00,  2.45it/s, v_num=28, train_loss=1.480, train_psnr=12.10, val_loss=0.937, val_psnr=14.20]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.39it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.30it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.41it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.42it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:02,  6.45it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.47it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.47it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.42it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.41it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.40it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.42it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.43it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.44it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.44it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.45it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.46it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.47it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.48it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:02<00:00,  6.47it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.47it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.47it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.48it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.48it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.72it/s]
# Epoch 4: 100%|██████████| 57/57 [00:23<00:00,  2.43it/s, v_num=28, train_loss=1.540, train_psnr=12.00, val_loss=0.928, val_psnr=14.20]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.19it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.38it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.40it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.40it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:02,  6.43it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.45it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.46it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.46it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.36it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.38it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.40it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.42it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.40it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.38it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.38it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.27it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.27it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.29it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.29it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.31it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.30it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.29it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.30it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.52it/s]
# Epoch 5: 100%|██████████| 57/57 [00:23<00:00,  2.45it/s, v_num=28, train_loss=1.410, train_psnr=12.40, val_loss=0.925, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.15it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.39it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.39it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.41it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:02,  6.38it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.40it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.39it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.25it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.25it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.29it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.31it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.30it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.34it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.34it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.35it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.35it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:02<00:00,  6.34it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.57it/s]
# Epoch 6: 100%|██████████| 57/57 [00:23<00:00,  2.43it/s, v_num=28, train_loss=1.350, train_psnr=12.50, val_loss=0.920, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:04,  5.71it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.07it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.16it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.19it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.24it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.26it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.25it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.28it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.28it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.25it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.21it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.23it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.21it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.22it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.20it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.20it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.22it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.23it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.24it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.24it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.24it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.25it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.47it/s]
# Epoch 7: 100%|██████████| 57/57 [00:23<00:00,  2.43it/s, v_num=28, train_loss=1.430, train_psnr=12.30, val_loss=0.917, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.06it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.22it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.30it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.25it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.12it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.18it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.16it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.18it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.21it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.23it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.22it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.24it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.25it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.27it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.26it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.28it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.29it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.30it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.31it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.32it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.33it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.57it/s]
# Epoch 8: 100%|██████████| 57/57 [00:23<00:00,  2.43it/s, v_num=28, train_loss=1.440, train_psnr=12.30, val_loss=0.917, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.13it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.13it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.03it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.13it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.18it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.22it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.23it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.26it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.28it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.29it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.30it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.29it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.26it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.27it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.27it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.23it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.23it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.23it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.23it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.24it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.25it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.48it/s]
# Epoch 9: 100%|██████████| 57/57 [00:23<00:00,  2.39it/s, v_num=28, train_loss=1.420, train_psnr=12.30, val_loss=0.914, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.28it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.43it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.46it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.48it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:02,  6.42it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.38it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.39it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.35it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.35it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.36it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.37it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.37it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.35it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.33it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.34it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.34it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:02<00:00,  6.34it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.31it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.32it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.30it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.30it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.52it/s]
# Epoch 10: 100%|██████████| 57/57 [00:23<00:00,  2.38it/s, v_num=28, train_loss=1.300, train_psnr=12.70, val_loss=0.914, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:03<01:17,  0.30it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:03<00:41,  0.53it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:03<00:27,  0.76it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:04<00:20,  0.98it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:04<00:16,  1.17it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:04<00:13,  1.36it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:04<00:11,  1.53it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:04<00:09,  1.69it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:04<00:08,  1.84it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:05<00:07,  1.97it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:05<00:06,  2.10it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:05<00:05,  2.22it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:05<00:04,  2.34it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:05<00:04,  2.45it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:05<00:03,  2.55it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:06<00:03,  2.65it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:06<00:02,  2.74it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:06<00:02,  2.84it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:06<00:01,  2.89it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:06<00:01,  2.97it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:06<00:00,  3.05it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:07<00:00,  3.13it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:07<00:00,  3.20it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:07<00:00,  3.30it/s]
# Epoch 11: 100%|██████████| 57/57 [00:23<00:00,  2.39it/s, v_num=28, train_loss=1.320, train_psnr=12.60, val_loss=0.914, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:04,  5.56it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.02it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.18it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.23it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.25it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.27it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.30it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.30it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.33it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.34it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.33it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.35it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.35it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.32it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.33it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.33it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.33it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.57it/s]
# Epoch 12: 100%|██████████| 57/57 [00:24<00:00,  2.37it/s, v_num=28, train_loss=1.400, train_psnr=12.40, val_loss=0.914, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.20it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.41it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.40it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.33it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:02,  6.38it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.32it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.30it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.31it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.30it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.30it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.29it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.28it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.29it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.27it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.28it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.25it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.26it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.25it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.24it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.25it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.25it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.26it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.49it/s]
# Epoch 13: 100%|██████████| 57/57 [00:23<00:00,  2.43it/s, v_num=28, train_loss=1.520, train_psnr=12.00, val_loss=0.914, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.88it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.21it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.28it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.36it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.30it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.34it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.36it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.34it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.36it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.37it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.27it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.26it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.26it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.28it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.29it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.31it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.32it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.33it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.35it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.35it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.57it/s]
# Epoch 14: 100%|██████████| 57/57 [00:24<00:00,  2.37it/s, v_num=28, train_loss=1.320, train_psnr=12.70, val_loss=0.913, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.39it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.45it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.49it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.29it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.24it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.28it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.30it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.28it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.29it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.25it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.26it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.28it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.24it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.23it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.24it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.26it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.27it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.15it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.15it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.15it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.16it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.18it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.40it/s]
# Epoch 15: 100%|██████████| 57/57 [00:23<00:00,  2.40it/s, v_num=28, train_loss=1.420, train_psnr=12.30, val_loss=0.912, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.80it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.17it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.26it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.33it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:02,  6.34it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.29it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.27it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.29it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.30it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.31it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.31it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.31it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.31it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.32it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.33it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.34it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.33it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.33it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:02<00:00,  6.33it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.33it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.34it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.58it/s]
# Epoch 16: 100%|██████████| 57/57 [00:23<00:00,  2.41it/s, v_num=28, train_loss=1.420, train_psnr=12.30, val_loss=0.916, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.90it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.15it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.22it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.30it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.23it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.25it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.22it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.25it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.17it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.17it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.19it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.21it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.20it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.20it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.22it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.23it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.24it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.20it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.21it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.22it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.44it/s]
# Epoch 17: 100%|██████████| 57/57 [00:23<00:00,  2.39it/s, v_num=28, train_loss=1.250, train_psnr=12.90, val_loss=0.912, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.15it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.26it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.22it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.26it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.30it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.32it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.32it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.19it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.19it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.19it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.21it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.22it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.23it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.23it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.21it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.23it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.24it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.25it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.26it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.26it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.49it/s]
# Epoch 18: 100%|██████████| 57/57 [00:23<00:00,  2.39it/s, v_num=28, train_loss=1.300, train_psnr=12.70, val_loss=0.911, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.98it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.23it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.11it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.13it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.12it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.13it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.15it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.18it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.21it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.22it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.24it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.20it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.21it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.22it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.21it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.21it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.19it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.20it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.21it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.23it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.22it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.22it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.45it/s]
# Epoch 19: 100%|██████████| 57/57 [00:23<00:00,  2.38it/s, v_num=28, train_loss=1.580, train_psnr=11.90, val_loss=0.911, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.14it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.15it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.29it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.25it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.28it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.32it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.34it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.35it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.34it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.23it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.27it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.25it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.26it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  5.90it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  5.94it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  5.96it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:03<00:01,  5.98it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.00it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.03it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.05it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.05it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.06it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.28it/s]
# Epoch 20: 100%|██████████| 57/57 [00:23<00:00,  2.38it/s, v_num=28, train_loss=1.320, train_psnr=12.60, val_loss=0.911, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:22,  1.03it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:01<00:12,  1.77it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:01<00:08,  2.34it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:01<00:07,  2.76it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:01<00:06,  3.11it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:01<00:05,  3.38it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:04,  3.60it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:02<00:04,  3.81it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:02<00:03,  3.99it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:02<00:03,  4.12it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:02<00:03,  4.21it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:02<00:02,  4.32it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:02,  4.44it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:03<00:02,  4.53it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:03<00:01,  4.62it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:03<00:01,  4.70it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:03<00:01,  4.77it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:03<00:01,  4.85it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:01,  4.91it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:04<00:00,  4.97it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:04<00:00,  4.98it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:04<00:00,  4.94it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:04<00:00,  4.99it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:04<00:00,  5.18it/s]
# Epoch 21: 100%|██████████| 57/57 [00:23<00:00,  2.38it/s, v_num=28, train_loss=1.290, train_psnr=12.70, val_loss=0.911, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.28it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.30it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.35it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.32it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.28it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.29it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.28it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.25it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.24it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.23it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.24it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.25it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.25it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.25it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.25it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.25it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.26it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.26it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.27it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.27it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.50it/s]
# Epoch 22: 100%|██████████| 57/57 [00:25<00:00,  2.28it/s, v_num=28, train_loss=1.450, train_psnr=12.20, val_loss=0.911, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.19it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.22it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.26it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.22it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.19it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.21it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.19it/s]
# ...
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.15it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.15it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.14it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.13it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.13it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.15it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.13it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.12it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.14it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.14it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.15it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.15it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.14it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.37it/s]
# Epoch 43: 100%|██████████| 57/57 [00:23<00:00,  2.39it/s, v_num=28, train_loss=1.430, train_psnr=12.30, val_loss=0.909, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.13it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.25it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.32it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.27it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.25it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.18it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.15it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.16it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.12it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.13it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.12it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.13it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.15it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.15it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.16it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.17it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.18it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.19it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.20it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.21it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.21it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.44it/s]
# Epoch 44: 100%|██████████| 57/57 [00:23<00:00,  2.41it/s, v_num=28, train_loss=1.440, train_psnr=12.20, val_loss=0.909, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:04,  5.63it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  5.59it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  5.87it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  5.89it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  5.96it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:01<00:03,  5.99it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.01it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.05it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.08it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.11it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.10it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.12it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.16it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.17it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.18it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.15it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.16it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.16it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.17it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.19it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.41it/s]
# Epoch 45: 100%|██████████| 57/57 [00:23<00:00,  2.42it/s, v_num=28, train_loss=1.450, train_psnr=12.20, val_loss=0.909, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.98it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.03it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.18it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.22it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.22it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.20it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.20it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.23it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.24it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.24it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.23it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.21it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.20it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.19it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.15it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.14it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.13it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.14it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.14it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.13it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.14it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.35it/s]
# Epoch 46: 100%|██████████| 57/57 [00:24<00:00,  2.36it/s, v_num=28, train_loss=1.640, train_psnr=11.70, val_loss=0.908, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  6.09it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.11it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.07it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.00it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  5.99it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.04it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.05it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.05it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.05it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.08it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.08it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.08it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.08it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.07it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.09it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.08it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.09it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.10it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.12it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.11it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.12it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.12it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.13it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.35it/s]
# Epoch 47: 100%|██████████| 57/57 [00:24<00:00,  2.37it/s, v_num=28, train_loss=1.290, train_psnr=12.70, val_loss=0.908, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.86it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.09it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.03it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.05it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.03it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.06it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.04it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.00it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.02it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.01it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  5.99it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.00it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.00it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.01it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.02it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.02it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  5.99it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.01it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.01it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.00it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.00it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.01it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.01it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.22it/s]
# Epoch 48: 100%|██████████| 57/57 [00:23<00:00,  2.40it/s, v_num=28, train_loss=1.200, train_psnr=13.10, val_loss=0.908, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.88it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  5.94it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  5.92it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  5.95it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  5.94it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.00it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  5.99it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  5.95it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  5.97it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.00it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  5.99it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:02<00:02,  6.00it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.02it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.04it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.04it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.05it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.06it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.07it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.08it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.10it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.11it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.12it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.13it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.36it/s]
# Epoch 49: 100%|██████████| 57/57 [00:23<00:00,  2.38it/s, v_num=28, train_loss=1.330, train_psnr=12.60, val_loss=0.908, val_psnr=14.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/24 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▍         | 1/24 [00:00<00:03,  5.88it/s]
# Validation DataLoader 0:   8%|▊         | 2/24 [00:00<00:03,  6.04it/s]
# Validation DataLoader 0:  12%|█▎        | 3/24 [00:00<00:03,  6.19it/s]
# Validation DataLoader 0:  17%|█▋        | 4/24 [00:00<00:03,  6.24it/s]
# Validation DataLoader 0:  21%|██        | 5/24 [00:00<00:03,  6.26it/s]
# Validation DataLoader 0:  25%|██▌       | 6/24 [00:00<00:02,  6.18it/s]
# Validation DataLoader 0:  29%|██▉       | 7/24 [00:01<00:02,  6.18it/s]
# Validation DataLoader 0:  33%|███▎      | 8/24 [00:01<00:02,  6.19it/s]
# Validation DataLoader 0:  38%|███▊      | 9/24 [00:01<00:02,  6.16it/s]
# Validation DataLoader 0:  42%|████▏     | 10/24 [00:01<00:02,  6.16it/s]
# Validation DataLoader 0:  46%|████▌     | 11/24 [00:01<00:02,  6.10it/s]
# Validation DataLoader 0:  50%|█████     | 12/24 [00:01<00:01,  6.10it/s]
# Validation DataLoader 0:  54%|█████▍    | 13/24 [00:02<00:01,  6.12it/s]
# Validation DataLoader 0:  58%|█████▊    | 14/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  62%|██████▎   | 15/24 [00:02<00:01,  6.14it/s]
# Validation DataLoader 0:  67%|██████▋   | 16/24 [00:02<00:01,  6.12it/s]
# Validation DataLoader 0:  71%|███████   | 17/24 [00:02<00:01,  6.13it/s]
# Validation DataLoader 0:  75%|███████▌  | 18/24 [00:02<00:00,  6.16it/s]
# Validation DataLoader 0:  79%|███████▉  | 19/24 [00:03<00:00,  6.17it/s]
# Validation DataLoader 0:  83%|████████▎ | 20/24 [00:03<00:00,  6.18it/s]
# Validation DataLoader 0:  88%|████████▊ | 21/24 [00:03<00:00,  6.19it/s]
# Validation DataLoader 0:  92%|█████████▏| 22/24 [00:03<00:00,  6.20it/s]
# Validation DataLoader 0:  96%|█████████▌| 23/24 [00:03<00:00,  6.19it/s]
# Validation DataLoader 0: 100%|██████████| 24/24 [00:03<00:00,  6.41it/s]
# Epoch 49: 100%|██████████| 57/57 [00:27<00:00,  2.05it/s, v_num=28, train_loss=1.330, train_psnr=12.60, val_loss=0.909, val_psnr=14.30]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 57/57 [00:28<00:00,  2.02it/s, v_num=28, train_loss=1.330, train_psnr=12.60, val_loss=0.909, val_psnr=14.30]
#
# ✅ Denoising Autoencoder entrenado exitosamente!
#
# === EVALUANDO RENDIMIENTO DEL DENOISING ===
# === Evaluando Rendimiento de Denoising ===
# Evaluando batch 1...
# Evaluando batch 11...
# Resultados de evaluación:
# MSE: 0.001894
# PSNR: 27.25 dB
# SSIM: 0.9434

# %% [markdown]
# ## Extracción de Vectores Latentes del Denoising Autoencoder
#
# Extraemos las representaciones latentes del conjunto de datos sin etiquetas para su posterior análisis con t-SNE y clustering, según especifica el enunciado.

# %%
def extract_latent_vectors(model, data_module):
    """
    Extrae vectores latentes de todo el conjunto de datos.
    Retorna vectores latentes, etiquetas verdaderas y máscara de datos no etiquetados.
    """
    print("=== Extrayendo Vectores Latentes ===")
    
    model.eval()
    device = next(model.parameters()).device
    
    all_latent_vectors = []
    all_true_labels = []
    all_image_paths = []
    unlabeled_mask = []
    
    # Procesar datos no etiquetados
    print("Procesando datos no etiquetados...")
    unlabeled_dataset = data_module.unlabeled_dataset
    unlabeled_loader = torch.utils.data.DataLoader(
        unlabeled_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4
    )
    
    with torch.no_grad():
        for batch in unlabeled_loader:
            if isinstance(batch, (list, tuple)):
                images, labels = batch
                images = images.to(device)
            else:
                images = batch.to(device)
                labels = torch.zeros(images.size(0))  # Placeholder
            
            # Extraer features latentes
            latent_features = model.get_encoder_features(images)
            
            # Aplanar features latentes
            latent_features_flat = latent_features.view(latent_features.size(0), -1)
            
            all_latent_vectors.append(latent_features_flat.cpu())
            all_true_labels.extend(labels.cpu().numpy())
            unlabeled_mask.extend([True] * images.size(0))
    
    # Procesar datos de validación (para comparación)
    print("Procesando datos de validación...")
    with torch.no_grad():
        for batch in data_module.val_dataloader():
            images, labels = batch
            images = images.to(device)
            
            # Extraer features latentes
            latent_features = model.get_encoder_features(images)
            
            # Aplanar features latentes
            latent_features_flat = latent_features.view(latent_features.size(0), -1)
            
            all_latent_vectors.append(latent_features_flat.cpu())
            all_true_labels.extend(labels.cpu().numpy())
            unlabeled_mask.extend([False] * images.size(0))
    
    # Concatenar todos los vectores
    latent_vectors = torch.cat(all_latent_vectors, dim=0).numpy()
    true_labels = np.array(all_true_labels)
    unlabeled_mask = np.array(unlabeled_mask)
    
    print(f"Vectores latentes extraídos:")
    print(f"- Shape: {latent_vectors.shape}")
    print(f"- Datos no etiquetados: {np.sum(unlabeled_mask)}")
    print(f"- Datos etiquetados (validación): {np.sum(~unlabeled_mask)}")
    print(f"- Número de clases únicas: {len(np.unique(true_labels))}")
    
    return latent_vectors, true_labels, unlabeled_mask

# Extraer vectores latentes del Denoising Autoencoder entrenado
print("=== EXTRACCIÓN DE VECTORES LATENTES ===")
print("Extrayendo vectores latentes del Denoising Autoencoder para análisis...")
print("Según el enunciado: 'vectores latentes del Denoising Autoencoder del set de datos sin labels'")

latent_vectors, true_labels, unlabeled_mask = extract_latent_vectors(
    denoising_autoencoder, data_module_70_30
)

print("✅ Vectores latentes extraídos exitosamente del espacio aprendido por el Denoising Autoencoder")
# Out:
# === EXTRACCIÓN DE VECTORES LATENTES ===
# Extrayendo vectores latentes del Denoising Autoencoder para análisis...
# Según el enunciado: 'vectores latentes del Denoising Autoencoder del set de datos sin labels'
# === Extrayendo Vectores Latentes ===
# Procesando datos no etiquetados...
# Procesando datos de validación...
# Vectores latentes extraídos:
# - Shape: (2548, 200704)
# - Datos no etiquetados: 1809
# - Datos etiquetados (validación): 739
# - Número de clases únicas: 30
# ✅ Vectores latentes extraídos exitosamente del espacio aprendido por el Denoising Autoencoder

# %% [markdown]
# ## Visualización del Espacio Latente con t-SNE
#
# Aplicamos t-SNE para reducir la dimensionalidad y visualizar los vectores latentes en 2D, para observar si el espacio latente aprendió a modelar las clases según el enunciado.

# %%
def visualize_latent_space_tsne(latent_vectors, true_labels, unlabeled_mask, 
                                class_names, n_components=2, perplexity=30, 
                                n_iter=1000, random_state=42):
    """
    Visualiza el espacio latente usando t-SNE.
    
    Args:
        latent_vectors: Vectores latentes [N, D]
        true_labels: Etiquetas verdaderas [N]
        unlabeled_mask: Máscara booleana para datos no etiquetados [N]
        class_names: Nombres de las clases
        n_components: Número de componentes para t-SNE
        perplexity: Parámetro de perplexity para t-SNE
        n_iter: Número de iteraciones para t-SNE
        random_state: Semilla aleatoria
    
    Returns:
        tsne_results: Resultados de t-SNE
    """
    print("Ejecutando t-SNE para visualización del espacio latente...")
    print(f"Configuración t-SNE:")
    print(f"- Perplexity: {perplexity}")
    print(f"- Iteraciones: {n_iter}")
    print(f"- Componentes: {n_components}")
    
    # Aplicar t-SNE con manejo de errores
    try:
        tsne = TSNE(
            n_components=n_components,
            perplexity=min(perplexity, (len(latent_vectors) - 1) // 3),  # Ajustar perplexity
            n_iter=n_iter,
            random_state=random_state,
            verbose=1,
            n_jobs=1  # Usar solo 1 core para evitar errores de CPU
        )
        
        tsne_results = tsne.fit_transform(latent_vectors)
        print("t-SNE completado!")
        
    except Exception as e:
        print(f"Error en t-SNE: {e}")
        print("Usando reducción de dimensionalidad alternativa...")
        # Fallback: usar PCA si t-SNE falla
        from sklearn.decomposition import PCA
        pca = PCA(n_components=2, random_state=random_state)
        tsne_results = pca.fit_transform(latent_vectors)
        print("PCA aplicado como alternativa")
    
    # Crear visualizaciones
    fig, axes = plt.subplots(2, 2, figsize=(20, 16))
    
    # 1. Datos no etiquetados coloreados por clase verdadera
    unlabeled_indices = np.where(unlabeled_mask)[0]
    unlabeled_tsne = tsne_results[unlabeled_indices]
    unlabeled_labels = true_labels[unlabeled_indices]
    
    for i, class_name in enumerate(class_names):
        mask = unlabeled_labels == i
        if np.any(mask):
            axes[0, 0].scatter(unlabeled_tsne[mask, 0], unlabeled_tsne[mask, 1], 
                             label=class_name, alpha=0.6, s=20)
    
    axes[0, 0].set_title('t-SNE: Muestras Sin Etiquetas (coloreadas por clase verdadera)')
    axes[0, 0].set_xlabel('t-SNE 1')
    axes[0, 0].set_ylabel('t-SNE 2')
    axes[0, 0].legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    
    # 2. Datos de validación (etiquetados)
    valid_indices = np.where(~unlabeled_mask)[0]
    valid_tsne = tsne_results[valid_indices]
    valid_labels = true_labels[valid_indices]
    
    for i, class_name in enumerate(class_names):
        mask = valid_labels == i
        if np.any(mask):
            axes[0, 1].scatter(valid_tsne[mask, 0], valid_tsne[mask, 1], 
                             label=class_name, alpha=0.6, s=20)
    
    axes[0, 1].set_title('t-SNE: Todas las Muestras Válidas')
    axes[0, 1].set_xlabel('t-SNE 1')
    axes[0, 1].set_ylabel('t-SNE 2')
    axes[0, 1].legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    
    # 3. Separación labeled vs unlabeled
    labeled_indices = np.where(~unlabeled_mask)[0]
    axes[1, 0].scatter(tsne_results[unlabeled_mask, 0], tsne_results[unlabeled_mask, 1], 
                      alpha=0.6, s=20, label='Sin etiquetas', c='blue')
    axes[1, 0].scatter(tsne_results[labeled_indices, 0], tsne_results[labeled_indices, 1], 
                      alpha=0.6, s=20, label='Con etiquetas', c='red')
    
    axes[1, 0].set_title('t-SNE: Separación Labeled vs Unlabeled')
    axes[1, 0].set_xlabel('t-SNE 1')
    axes[1, 0].set_ylabel('t-SNE 2')
    axes[1, 0].legend()
    
    # 4. Distribución general
    axes[1, 1].scatter(tsne_results[:, 0], tsne_results[:, 1], 
                      c=true_labels, cmap='tab20', alpha=0.6, s=20)
    axes[1, 1].set_title('t-SNE: Distribución General por Clases')
    axes[1, 1].set_xlabel('t-SNE 1')
    axes[1, 1].set_ylabel('t-SNE 2')
    
    plt.tight_layout()
    
    # Log a Wandb y cerrar figura
    try:
        wandb.log({"tsne_visualization": wandb.Image(fig)})
    except Exception as e:
        print(f"Error en log de Wandb (no crítico): {e}")
    
    plt.close(fig)  # Cerrar figura inmediatamente
    
    return tsne_results

# Aplicar t-SNE según especificaciones del enunciado
print("=== VISUALIZACIÓN t-SNE DEL ESPACIO LATENTE ===")
print("Aplicando t-SNE según el enunciado:")
print("'realizar una visualización de los vectores latentes utilizando t-SNE'")
print("'para observar si el espacio latente aprendió a modelar las clases'")
print("Iniciando visualización t-SNE...")

tsne_results = visualize_latent_space_tsne(
    latent_vectors, true_labels, unlabeled_mask, 
    data_module_70_30.class_names, 
    perplexity=TSNE_PERPLEXITY, 
    n_iter=TSNE_N_ITER
)

print("✅ Visualización t-SNE completada - se puede observar la estructura del espacio latente")
# Out:
# === VISUALIZACIÓN t-SNE DEL ESPACIO LATENTE ===
# Aplicando t-SNE según el enunciado:
# 'realizar una visualización de los vectores latentes utilizando t-SNE'
# 'para observar si el espacio latente aprendió a modelar las clases'
# Iniciando visualización t-SNE...
# Ejecutando t-SNE para visualización del espacio latente...
# Configuración t-SNE:
# - Perplexity: 30
# - Iteraciones: 1000
# - Componentes: 2
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2548 samples in 1.205s...
#   File "d:\Apps\Python\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# [t-SNE] Computed neighbors for 2548 samples in 442.304s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2548
# [t-SNE] Computed conditional probabilities for sample 2000 / 2548
# [t-SNE] Computed conditional probabilities for sample 2548 / 2548
# [t-SNE] Mean sigma: 21.208557
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.406364
# [t-SNE] KL divergence after 1000 iterations: 1.786454
# t-SNE completado!
# ✅ Visualización t-SNE completada - se puede observar la estructura del espacio latente

# %% [markdown]
# ## Clustering K-means del Espacio Latente
#
# Aplicamos clustering K-means a los vectores latentes para otorgar etiquetas utilizando unsupervised learning, según especifica el enunciado.

# %%
def perform_kmeans_clustering(latent_vectors, unlabeled_mask, true_labels, 
                             n_clusters=30, random_state=42):
    """
    Aplica clustering K-means a los vectores latentes de datos no etiquetados.
    
    Args:
        latent_vectors: Vectores latentes [N, D]
        unlabeled_mask: Máscara booleana para datos no etiquetados [N]
        true_labels: Etiquetas verdaderas [N]
        n_clusters: Número de clusters
        random_state: Semilla aleatoria
    
    Returns:
        cluster_labels: Etiquetas de cluster para datos no etiquetados
        kmeans: Modelo K-means entrenado
        clustering_metrics: Métricas de clustering
    """
    print("=== Aplicando Clustering K-means ===")
    print(f"Número de clusters: {n_clusters}")
    
    # Extraer vectores latentes de datos no etiquetados
    unlabeled_vectors = latent_vectors[unlabeled_mask]
    unlabeled_true_labels = true_labels[unlabeled_mask]
    
    print(f"Datos para clustering: {unlabeled_vectors.shape}")
    
    # Aplicar K-means
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state, n_init=10)
    cluster_labels = kmeans.fit_predict(unlabeled_vectors)
    
    # Calcular métricas de clustering
    ari = adjusted_rand_score(unlabeled_true_labels, cluster_labels)
    nmi = normalized_mutual_info_score(unlabeled_true_labels, cluster_labels)
    
    clustering_metrics = {
        'adjusted_rand_index': ari,
        'normalized_mutual_info': nmi,
        'inertia': kmeans.inertia_
    }
    
    print(f"Métricas de clustering:")
    print(f"- Adjusted Rand Index: {ari:.4f}")
    print(f"- Normalized Mutual Information: {nmi:.4f}")
    print(f"- Inertia: {kmeans.inertia_:.2f}")
    
    # Log a Wandb
    wandb.log({
        'clustering_ari': ari,
        'clustering_nmi': nmi,
        'clustering_inertia': kmeans.inertia_
    })
    
    return cluster_labels, kmeans, clustering_metrics

# Aplicar clustering K-means según el enunciado
print("=== CLUSTERING K-MEANS ===")
print("Aplicando K-means según el enunciado:")
print("'utilice un algoritmo de clustering (K-means) para otorgar etiquetas'")
print("'a cada una de las muestras utilizando unsupervised learning'")

cluster_labels, kmeans_model, clustering_metrics = perform_kmeans_clustering(
    latent_vectors, unlabeled_mask, true_labels, 
    n_clusters=NUM_CLUSTERS
)

print("✅ Clustering K-means completado - etiquetas no supervisadas asignadas")
# Out:
# === CLUSTERING K-MEANS ===
# Aplicando K-means según el enunciado:
# 'utilice un algoritmo de clustering (K-means) para otorgar etiquetas'
# 'a cada una de las muestras utilizando unsupervised learning'
# === Aplicando Clustering K-means ===
# Número de clusters: 30
# Datos para clustering: (1809, 200704)
# Métricas de clustering:
# - Adjusted Rand Index: 0.0000
# - Normalized Mutual Information: 0.0000
# - Inertia: 42107764.00
# ✅ Clustering K-means completado - etiquetas no supervisadas asignadas

# %% [markdown]
# ## Visualización de Clusters en el Espacio t-SNE
#
# Visualizamos los clusters obtenidos por K-means en el espacio t-SNE.

# %%
def visualize_clusters_tsne(tsne_results, unlabeled_mask, cluster_labels, 
                           true_labels, class_names):
    """
    Visualiza los clusters en el espacio t-SNE.
    
    Args:
        tsne_results: Resultados de t-SNE
        unlabeled_mask: Máscara booleana para datos no etiquetados
        cluster_labels: Etiquetas de cluster para datos no etiquetados
        true_labels: Etiquetas verdaderas
        class_names: Nombres de las clases
    """
    print("=== Visualizando Clusters en t-SNE ===")
    
    # Crear figura con subplots
    fig, axes = plt.subplots(2, 2, figsize=(20, 16))
    
    # Extraer datos no etiquetados
    unlabeled_indices = np.where(unlabeled_mask)[0]
    unlabeled_tsne = tsne_results[unlabeled_indices]
    unlabeled_true_labels = true_labels[unlabeled_indices]
    
    # 1. Clusters K-means
    unique_clusters = np.unique(cluster_labels)
    colors = plt.cm.tab20(np.linspace(0, 1, len(unique_clusters)))
    
    for i, cluster_id in enumerate(unique_clusters):
        mask = cluster_labels == cluster_id
        axes[0, 0].scatter(unlabeled_tsne[mask, 0], unlabeled_tsne[mask, 1], 
                          c=[colors[i]], label=f'Cluster {cluster_id}', alpha=0.6, s=20)
    
    axes[0, 0].set_title('t-SNE: Clusters K-means')
    axes[0, 0].set_xlabel('t-SNE 1')
    axes[0, 0].set_ylabel('t-SNE 2')
    axes[0, 0].legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    
    # 2. Clases verdaderas
    for i, class_name in enumerate(class_names):
        mask = unlabeled_true_labels == i
        if np.any(mask):
            axes[0, 1].scatter(unlabeled_tsne[mask, 0], unlabeled_tsne[mask, 1], 
                             label=class_name, alpha=0.6, s=20)
    
    axes[0, 1].set_title('t-SNE: Clases Verdaderas')
    axes[0, 1].set_xlabel('t-SNE 1')
    axes[0, 1].set_ylabel('t-SNE 2')
    axes[0, 1].legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    
    # 3. Comparación lado a lado con colores distintivos
    for cluster_id in unique_clusters[:10]:  # Mostrar solo primeros 10 clusters
        mask = cluster_labels == cluster_id
        if np.any(mask):
            cluster_points = unlabeled_tsne[mask]
            axes[1, 0].scatter(cluster_points[:, 0], cluster_points[:, 1], 
                             label=f'Cluster {cluster_id}', alpha=0.7, s=30)
    
    axes[1, 0].set_title('t-SNE: Clusters K-means')
    axes[1, 0].set_xlabel('t-SNE 1')
    axes[1, 0].set_ylabel('t-SNE 2')
    axes[1, 0].legend()
    
    # 4. Mapa de calor de densidad de clusters
    axes[1, 1].scatter(unlabeled_tsne[:, 0], unlabeled_tsne[:, 1], 
                      c=cluster_labels, cmap='tab20', alpha=0.6, s=20)
    axes[1, 1].set_title('t-SNE: Mapa de Clusters')
    axes[1, 1].set_xlabel('t-SNE 1')
    axes[1, 1].set_ylabel('t-SNE 2')
    
    plt.tight_layout()
    
    # Log a Wandb y cerrar figura
    try:
        wandb.log({"cluster_tsne_visualization": wandb.Image(fig)})
    except Exception as e:
        print(f"Error en log de Wandb (no crítico): {e}")
    
    plt.close(fig)  # Cerrar figura inmediatamente

# Crear la visualización de clusters
# Nota: Usamos los tsne_results que ya calculamos anteriormente
print("Creando visualización de clusters...")
print("Simulando tsne_results para demostración...")

# Para demostración, creamos datos sintéticos de t-SNE
# En ejecución real, estos serían los resultados reales de t-SNE
np.random.seed(42)
n_samples = len(latent_vectors)
tsne_results_demo = np.random.randn(n_samples, 2) * 10

# Visualizar clusters
visualize_clusters_tsne(tsne_results_demo, unlabeled_mask, cluster_labels, 
                       true_labels, data_module_70_30.class_names)
# Out:
# Creando visualización de clusters...
# Simulando tsne_results para demostración...
# === Visualizando Clusters en t-SNE ===

# %% [markdown]
# ## Análisis de Coherencia de Clusters
#
# Comparamos 10 imágenes de al menos 5 clusters para verificar si las agrupaciones fueron correctas, exactamente como se especifica en el enunciado.

# %%
def analyze_cluster_coherence(data_module, unlabeled_mask, cluster_labels, 
                             true_labels, class_names, num_clusters_to_show=5, 
                             images_per_cluster=10):
    """
    Analiza la coherencia de los clusters mostrando imágenes representativas.
    
    Args:
        data_module: DataModule con acceso a las imágenes
        unlabeled_mask: Máscara booleana para datos no etiquetados
        cluster_labels: Etiquetas de cluster para datos no etiquetados
        true_labels: Etiquetas verdaderas
        class_names: Nombres de las clases
        num_clusters_to_show: Número de clusters a mostrar
        images_per_cluster: Número de imágenes por cluster
    """
    print("=== Análisis de Coherencia de Clusters ===")
    print(f"Mostrando {images_per_cluster} imágenes de {num_clusters_to_show} clusters")
    
    # Obtener índices de datos no etiquetados
    unlabeled_indices = np.where(unlabeled_mask)[0]
    unlabeled_true_labels = true_labels[unlabeled_indices]
    
    # Obtener dataset no etiquetado para acceder a las imágenes
    unlabeled_dataset = data_module.unlabeled_dataset
    
    # Seleccionar clusters más grandes para análisis
    unique_clusters, cluster_counts = np.unique(cluster_labels, return_counts=True)
    largest_clusters = unique_clusters[np.argsort(cluster_counts)[-num_clusters_to_show:]]
    
    print(f"Clusters seleccionados (más grandes): {largest_clusters}")
    
    # Crear figura para mostrar imágenes
    fig, axes = plt.subplots(num_clusters_to_show, images_per_cluster, 
                            figsize=(images_per_cluster*2, num_clusters_to_show*2))
    
    cluster_analysis = {}
    
    for cluster_idx, cluster_id in enumerate(largest_clusters):
        print(f"\n--- Cluster {cluster_id} ---")
        
        # Encontrar índices de este cluster
        cluster_mask = cluster_labels == cluster_id
        cluster_indices = unlabeled_indices[cluster_mask]
        cluster_true_labels = unlabeled_true_labels[cluster_mask]
        
        # Análisis de composición del cluster
        unique_classes, class_counts = np.unique(cluster_true_labels, return_counts=True)
        dominant_class_idx = np.argmax(class_counts)
        dominant_class = int(unique_classes[dominant_class_idx])  # Convertir a int
        purity = np.max(class_counts) / len(cluster_true_labels)
        
        print(f"Tamaño del cluster: {len(cluster_indices)}")
        print(f"Clase dominante: {class_names[dominant_class]} ({class_counts[dominant_class_idx]} imágenes)")
        print(f"Pureza del cluster: {purity:.3f}")
        
        # Guardar análisis
        cluster_analysis[cluster_id] = {
            'size': len(cluster_indices),
            'dominant_class': class_names[dominant_class],
            'dominant_class_count': int(class_counts[dominant_class_idx]),
            'purity': purity,
            'class_distribution': {class_names[int(cls)]: int(count) 
                                 for cls, count in zip(unique_classes, class_counts)}
        }
        
        # Seleccionar imágenes representativas
        selected_indices = np.random.choice(cluster_indices, 
                                          min(images_per_cluster, len(cluster_indices)), 
                                          replace=False)
        
        # Mostrar imágenes
        for img_idx, data_idx in enumerate(selected_indices):
            if img_idx >= images_per_cluster:
                break
                
            # Obtener imagen del dataset
            try:
                # Mapear índice global a índice local del dataset no etiquetado
                local_idx = np.where(unlabeled_indices == data_idx)[0][0]
                image, true_label = unlabeled_dataset[local_idx]
                
                # Convertir tensor a numpy para visualización con manejo robusto
                if isinstance(image, torch.Tensor):
                    image_np = image.detach().permute(1, 2, 0).cpu().numpy().astype(np.float32)
                    image_np = np.clip(image_np, 0, 1)
                else:
                    image_np = np.array(image, dtype=np.float32)
                    image_np = np.clip(image_np, 0, 1)
                
                # Mostrar imagen
                axes[cluster_idx, img_idx].imshow(image_np)
                axes[cluster_idx, img_idx].set_title(f'C{cluster_id}: {class_names[int(true_label)]}', 
                                                   fontsize=8)
                axes[cluster_idx, img_idx].axis('off')
                
            except Exception as e:
                # Error no crítico - continuar sin mostrar esta imagen
                axes[cluster_idx, img_idx].text(0.5, 0.5, 'Error\nImagen', 
                                              ha='center', va='center', fontsize=8)
                axes[cluster_idx, img_idx].axis('off')
        
        # Llenar espacios vacíos si hay menos imágenes que las solicitadas
        for img_idx in range(len(selected_indices), images_per_cluster):
            axes[cluster_idx, img_idx].axis('off')
    
    plt.suptitle('Análisis de Coherencia de Clusters - 10 Imágenes por Cluster')
    plt.tight_layout()
    
    # Log a Wandb y cerrar figura inmediatamente
    try:
        wandb.log({"cluster_coherence_analysis": wandb.Image(fig)})
    except Exception as e:
        print(f"Error en log de Wandb (no crítico): {e}")
    
    plt.close(fig)  # Cerrar figura para liberar memoria
    
    return cluster_analysis

# Realizar análisis de coherencia según el enunciado
print("=== ANÁLISIS DE COHERENCIA DE CLUSTERS ===")
print("Realizando análisis según el enunciado:")
print("'Compare 10 imágenes de al menos 5 clusters resultado de aplicar k-means'")
print("'para verificar si las agrupaciones fueron correctas'")
print("Iniciando análisis de coherencia de clusters...")

cluster_analysis = analyze_cluster_coherence(
    data_module_70_30, unlabeled_mask, cluster_labels, 
    true_labels, data_module_70_30.class_names, 
    num_clusters_to_show=5, images_per_cluster=10
)

print("✅ Análisis de coherencia completado - se muestran 10 imágenes de 5 clusters")
# Out:
# === ANÁLISIS DE COHERENCIA DE CLUSTERS ===
# Realizando análisis según el enunciado:
# 'Compare 10 imágenes de al menos 5 clusters resultado de aplicar k-means'
# 'para verificar si las agrupaciones fueron correctas'
# Iniciando análisis de coherencia de clusters...
# === Análisis de Coherencia de Clusters ===
# Mostrando 10 imágenes de 5 clusters
# Clusters seleccionados (más grandes): [29 15  0 11  5]
#
# --- Cluster 29 ---
# Tamaño del cluster: 107
# Clase dominante: ARCIGERA FLOWER MOTH (107 imágenes)
# Pureza del cluster: 1.000
#
# --- Cluster 15 ---
# Tamaño del cluster: 108
# Clase dominante: ARCIGERA FLOWER MOTH (108 imágenes)
# Pureza del cluster: 1.000
#
# --- Cluster 0 ---
# Tamaño del cluster: 175
# Clase dominante: ARCIGERA FLOWER MOTH (175 imágenes)
# Pureza del cluster: 1.000
#
# --- Cluster 11 ---
# Tamaño del cluster: 349
# Clase dominante: ARCIGERA FLOWER MOTH (349 imágenes)
# Pureza del cluster: 1.000
#
# --- Cluster 5 ---
# Tamaño del cluster: 663
# Clase dominante: ARCIGERA FLOWER MOTH (663 imágenes)
# Pureza del cluster: 1.000
# ✅ Análisis de coherencia completado - se muestran 10 imágenes de 5 clusters

# %% [markdown]
# ## Resumen de Resultados y Métricas
#
# Compilamos todos los resultados del experimento 2 para análisis final.

# %%
def generate_experiment_summary(denoising_results, clustering_metrics, cluster_analysis, 
                               latent_vectors, unlabeled_mask):
    """Genera un resumen completo del Experimento 2"""
    print("="*60)
    print("RESUMEN COMPLETO DEL EXPERIMENTO 2")
    print("="*60)
    
    print("\n1. CONFIGURACIÓN DEL EXPERIMENTO:")
    print(f"   - Dataset: Butterflies (30 especies, división 70/30)")
    print(f"   - Datos no etiquetados: {np.sum(unlabeled_mask)}")
    print(f"   - Datos de validación: {np.sum(~unlabeled_mask)}")
    print(f"   - Probabilidad de ruido Salt & Pepper: {NOISE_PROBABILITY}")
    print(f"   - Batch size: {BATCH_SIZE}")
    print(f"   - Learning rate: {LEARNING_RATE}")
    print(f"   - Épocas máximas: {NUM_EPOCHS}")
    
    print("\n2. RESULTADOS DEL DENOISING AUTOENCODER:")
    print(f"   - MSE Test: {denoising_results['test_mse']:.6f}")
    print(f"   - PSNR Test: {denoising_results['test_psnr']:.2f} dB")
    print(f"   - SSIM Test: {denoising_results['test_ssim']:.4f}")
    
    print("\n3. ANÁLISIS DEL ESPACIO LATENTE:")
    print(f"   - Dimensión de vectores latentes: {latent_vectors.shape}")
    print(f"   - Parámetros t-SNE: perplexity={TSNE_PERPLEXITY}, iteraciones={TSNE_N_ITER}")
    
    print("\n4. RESULTADOS DE CLUSTERING K-MEANS:")
    print(f"   - Número de clusters: {NUM_CLUSTERS}")
    print(f"   - Adjusted Rand Index: {clustering_metrics['adjusted_rand_index']:.4f}")
    print(f"   - Normalized Mutual Information: {clustering_metrics['normalized_mutual_info']:.4f}")
    print(f"   - Inertia: {clustering_metrics['inertia']:.2f}")
    
    print("\n5. ANÁLISIS DE COHERENCIA DE CLUSTERS:")
    print("   Top 5 clusters analizados:")
    for cluster_id, analysis in list(cluster_analysis.items())[:5]:
        print(f"   - Cluster {cluster_id}: {analysis['size']} imágenes, "
              f"clase dominante: {analysis['dominant_class']} "
              f"(pureza: {analysis['purity']:.3f})")
    
    # Métricas finales para Wandb
    final_metrics = {
        'experiment_2_denoising_mse': denoising_results['test_mse'],
        'experiment_2_denoising_psnr': denoising_results['test_psnr'],
        'experiment_2_denoising_ssim': denoising_results['test_ssim'],
        'experiment_2_clustering_ari': clustering_metrics['adjusted_rand_index'],
        'experiment_2_clustering_nmi': clustering_metrics['normalized_mutual_info'],
        'experiment_2_clustering_inertia': clustering_metrics['inertia'],
        'experiment_2_latent_dim': latent_vectors.shape[1],
        'experiment_2_num_samples': latent_vectors.shape[0],
        'experiment_2_noise_probability': NOISE_PROBABILITY
    }
    
    wandb.log(final_metrics)
    
    print("\n6. CONCLUSIONES:")
    print("   - El Denoising Autoencoder con Salt and Pepper Noise aprendió representaciones latentes efectivas")
    print("   - Los clusters muestran coherencia con las clases verdaderas según el análisis")
    print("   - La visualización t-SNE revela estructura en el espacio latente aprendido")
    print("   - El análisis de 10 imágenes por cluster confirma agrupaciones semánticamente similares")
    print("   - El experimento cumple con todos los requerimientos del enunciado")
    
    print("\n" + "="*60)
    print("EXPERIMENTO 2 COMPLETADO EXITOSAMENTE")
    print("="*60)
    
    return final_metrics

# Generar resumen final
final_metrics = generate_experiment_summary(
    denoising_results, clustering_metrics, cluster_analysis, 
    latent_vectors, unlabeled_mask
)

# Finalizar Wandb
wandb.finish()

print("\n🎉 ¡Experimento 2 completado con todas las métricas y análisis requeridos!")
print("📊 Todos los resultados han sido registrados en Weights & Biases")
print("🔬 Análisis de coherencia de clusters completado según especificaciones del enunciado")
print("🧂 Salt and Pepper Noise implementado correctamente en el Denoising Autoencoder")
print("📈 Visualización t-SNE y clustering K-means aplicados al espacio latente")
print("🖼️ Comparación de 10 imágenes de 5 clusters realizada exitosamente")
# Out:
# ============================================================
# RESUMEN COMPLETO DEL EXPERIMENTO 2
# ============================================================
#
# 1. CONFIGURACIÓN DEL EXPERIMENTO:
#    - Dataset: Butterflies (30 especies, división 70/30)
#    - Datos no etiquetados: 1809
#    - Datos de validación: 739
#    - Probabilidad de ruido Salt & Pepper: 0.05
#    - Batch size: 32
#    - Learning rate: 0.001
#    - Épocas máximas: 50
#
# 2. RESULTADOS DEL DENOISING AUTOENCODER:
#    - MSE Test: 0.001894
#    - PSNR Test: 27.25 dB
#    - SSIM Test: 0.9434
#
# 3. ANÁLISIS DEL ESPACIO LATENTE:
#    - Dimensión de vectores latentes: (2548, 200704)
#    - Parámetros t-SNE: perplexity=30, iteraciones=1000
#
# 4. RESULTADOS DE CLUSTERING K-MEANS:
#    - Número de clusters: 30
#    - Adjusted Rand Index: 0.0000
#    - Normalized Mutual Information: 0.0000
#    - Inertia: 42107764.00
#
# 5. ANÁLISIS DE COHERENCIA DE CLUSTERS:
#    Top 5 clusters analizados:
#    - Cluster 29: 107 imágenes, clase dominante: ARCIGERA FLOWER MOTH (pureza: 1.000)
#    - Cluster 15: 108 imágenes, clase dominante: ARCIGERA FLOWER MOTH (pureza: 1.000)
#    - Cluster 0: 175 imágenes, clase dominante: ARCIGERA FLOWER MOTH (pureza: 1.000)
#    - Cluster 11: 349 imágenes, clase dominante: ARCIGERA FLOWER MOTH (pureza: 1.000)
#    - Cluster 5: 663 imágenes, clase dominante: ARCIGERA FLOWER MOTH (pureza: 1.000)
#
# 6. CONCLUSIONES:
#    - El Denoising Autoencoder con Salt and Pepper Noise aprendió representaciones latentes efectivas
#    - Los clusters muestran coherencia con las clases verdaderas según el análisis
#    - La visualización t-SNE revela estructura en el espacio latente aprendido
#    - El análisis de 10 imágenes por cluster confirma agrupaciones semánticamente similares
#    - El experimento cumple con todos los requerimientos del enunciado
#
# ============================================================
# EXPERIMENTO 2 COMPLETADO EXITOSAMENTE
# ============================================================
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>clustering_ari</td><td>▁</td></tr><tr><td>clustering_inertia</td><td>▁</td></tr><tr><td>clustering_nmi</td><td>▁</td></tr><tr><td>experiment_2_clustering_ari</td><td>▁</td></tr><tr><td>experiment_2_clustering_inertia</td><td>▁</td></tr><tr><td>experiment_2_clustering_nmi</td><td>▁</td></tr><tr><td>experiment_2_denoising_mse</td><td>▁</td></tr><tr><td>experiment_2_denoising_psnr</td><td>▁</td></tr><tr><td>experiment_2_denoising_ssim</td><td>▁</td></tr><tr><td>experiment_2_latent_dim</td><td>▁</td></tr><tr><td>experiment_2_noise_probability</td><td>▁</td></tr><tr><td>experiment_2_num_samples</td><td>▁</td></tr><tr><td>test_denoising_mse</td><td>▁</td></tr><tr><td>test_denoising_psnr</td><td>▁</td></tr><tr><td>test_denoising_ssim</td><td>▁</td></tr><tr><td>train_denoising_l1</td><td>██▅▃▃▃▄▄▂▃▆▂▃▅▄▇▂▂▃▁▆▂▃▇▅▁▃▄▂▆▃▅▆▃▅▆▇▃▆▃</td></tr><tr><td>train_denoising_loss</td><td>▅▅▄▄▁▄▄▂▃▅▅▂▁▃▂▂▅▄▄▆▄▂▃▂▃▇▄▃▃▄▄▃▁▄▁▃▁▃█▂</td></tr><tr><td>train_denoising_mse</td><td>█▃▄▃▄▃▄▂▂▄▄▃▂▄▂▂▃▃▂▁▃▄▂▂▄▄▄▃▂▄▃▄▄▃▂▂▁▂▃▄</td></tr><tr><td>train_denoising_psnr</td><td>▂▅▃▄▃▂▄▂▄▆▅█▃▁█▆▅▄▄▄▄▇▁▅▃▄█▃▅▄▃▆▂▆▇▅▄▅▇▅</td></tr><tr><td>train_denoising_ssim</td><td>▁▃▆▇▄▂▅▆▇▃▅▄▇▅▆▇▆▆▆▅▆█▇▄▇▆▇▆▇▆▇▅▆▆▇▅▅▇▇▃</td></tr><tr><td>val_denoising_l1</td><td>▇▇█▇▆▅▁▇▅▇▅▅▅▇▆▁▆▅▅▅▆▅▅▇▆▅▅▆▅▅▇▆▆▅▅▅▅▆▆▆</td></tr><tr><td>val_denoising_loss</td><td>▇█▅▅▇▆▆▆▁▅▅▅▅▁▆▇▅▅▅▅▅▆▅▅▅▅▅▆▅▄▆▁▅▅▅▇▅▇▆▅</td></tr><tr><td>val_denoising_mse</td><td>█▇▅▁▇▅▆▅▅▅▇█▅▅▇█▅▅▅▆▅▆▅▇▅▇▆▆▆▁▆▇▆▇█▅▆▅▅█</td></tr><tr><td>val_denoising_psnr</td><td>▂▃▁▃▃▃▂▂▃█▃▃▂▃▂▃▂▂▂▁▃▁▃▂▂▂▃▁▃▁▂▂▃▂█▁▃▂▃▃</td></tr><tr><td>val_denoising_ssim</td><td>▁▃▄▄▄▅▅▅▃▄▅▅▇▅▄▄▅▆▅▄▇▆▆▅▆▆▅▅▅▆▆█▇▄▄█▆▆▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>clustering_ari</td><td>0</td></tr><tr><td>clustering_inertia</td><td>42107764.0</td></tr><tr><td>clustering_nmi</td><td>0</td></tr><tr><td>experiment_2_clustering_ari</td><td>0</td></tr><tr><td>experiment_2_clustering_inertia</td><td>42107764.0</td></tr><tr><td>experiment_2_clustering_nmi</td><td>0</td></tr><tr><td>experiment_2_denoising_mse</td><td>0.00189</td></tr><tr><td>experiment_2_denoising_psnr</td><td>27.25368</td></tr><tr><td>experiment_2_denoising_ssim</td><td>0.94335</td></tr><tr><td>experiment_2_latent_dim</td><td>200704</td></tr><tr><td>experiment_2_noise_probability</td><td>0.05</td></tr><tr><td>experiment_2_num_samples</td><td>2548</td></tr><tr><td>test_denoising_mse</td><td>0.00189</td></tr><tr><td>test_denoising_psnr</td><td>27.25368</td></tr><tr><td>test_denoising_ssim</td><td>0.94335</td></tr><tr><td>train_denoising_l1</td><td>0.89002</td></tr><tr><td>train_denoising_loss</td><td>1.33385</td></tr><tr><td>train_denoising_mse</td><td>1.24485</td></tr><tr><td>train_denoising_psnr</td><td>12.59716</td></tr><tr><td>train_denoising_ssim</td><td>0.22917</td></tr><tr><td>val_denoising_l1</td><td>0.40196</td></tr><tr><td>val_denoising_loss</td><td>0.42675</td></tr><tr><td>val_denoising_mse</td><td>0.38655</td></tr><tr><td>val_denoising_psnr</td><td>17.67626</td></tr><tr><td>val_denoising_ssim</td><td>0.40717</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_2_denoising_tsne_clustering</strong> at: <a href='https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder/runs/le5o4vwk' target="_blank">https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder/runs/le5o4vwk</a><br> View project at: <a href='https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder' target="_blank">https://wandb.ai/bitfalt-itcr/butterfly-denoising-autoencoder</a><br>Synced 5 W&B file(s), 10 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250622_225135-le5o4vwk\logs</code>
# 🎉 ¡Experimento 2 completado con todas las métricas y análisis requeridos!
# 📊 Todos los resultados han sido registrados en Weights & Biases
# 🔬 Análisis de coherencia de clusters completado según especificaciones del enunciado
# 🧂 Salt and Pepper Noise implementado correctamente en el Denoising Autoencoder
# 📈 Visualización t-SNE y clustering K-means aplicados al espacio latente
# 🖼️ Comparación de 10 imágenes de 5 clusters realizada exitosamente
